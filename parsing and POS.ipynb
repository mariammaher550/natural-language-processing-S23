# %% [markdown]
# # Parsing & POS application
#
# ```
# Plan :
#   1. Parts of Speech (POS) Tagging
#   2. Shallow Parsing or Chunking
#   3. Constituency Parsing
#   4. Dependency Parsing
#   5. Application of POS (Named Entity Recognition)
# ```

# %% [markdown]
# ## 1. Parts of Speech (POS) Tagging
#
#
# 1. Use Spacy and NLTK and compare the results
#
#
# **More details in next lab**

# %%
import nltk
from nltk import word_tokenize

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('tagsets')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\maria\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\maria\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package tagsets to
# [nltk_data]     C:\Users\maria\AppData\Roaming\nltk_data...
# [nltk_data]   Package tagsets is already up-to-date!
# True

# %%
sentence = word_tokenize("allow us to add lines in list of allow actions")
print(sentence)
nltk.pos_tag(sentence)
# Out:
# ['allow', 'us', 'to', 'add', 'lines', 'in', 'list', 'of', 'allow', 'actions']
# [('allow', 'VB'),
#  ('us', 'PRP'),
#  ('to', 'TO'),
#  ('add', 'VB'),
#  ('lines', 'NNS'),
#  ('in', 'IN'),
#  ('list', 'NN'),
#  ('of', 'IN'),
#  ('allow', 'JJ'),
#  ('actions', 'NNS')]

# %% [markdown]
# ### 1.1 Try it yourself
#
# Using Python libraries, download Wikipedia's page on topic of your choice and tag the text parts of speech.
#
# You can use wikipedia api to retrieve the wikipedia page : [`pip install Wikipedia-API`](https://pypi.org/project/Wikipedia-API/)

# %%
# !pip install wikipedia-API
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wikipedia-API
#   Downloading Wikipedia_API-0.5.8-py3-none-any.whl (13 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from wikipedia-API) (2.25.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->wikipedia-API) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->wikipedia-API) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->wikipedia-API) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->wikipedia-API) (2022.12.7)
# Installing collected packages: wikipedia-API
# Successfully installed wikipedia-API-0.5.8

# %%
# based on https://wikipedia-api.readthedocs.io/en/latest/README.html?badge=latest
import wikipediaapi
wiki_wiki = wikipediaapi.Wikipedia('en')
page_py = wiki_wiki.page('Python_(programming_language)')

text = page_py.text
tokens= word_tokenize(text)
nltk.pos_tag(tokens)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-25-57baba739dc5> in <module>
#       1 # based on https://wikipedia-api.readthedocs.io/en/latest/README.html?badge=latest
# ----> 2 import wikipediaapi
#       3 wiki_wiki = wikipediaapi.Wikipedia('en')
#       4 page_py = wiki_wiki.page('Python_(programming_language)')
#       5
#
# ModuleNotFoundError: No module named 'wikipediaapi'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ## 2. Shallow Parsing or Chunking
#
# A process of extracting phrases from unstructured text. Chunking groups adjacent tokens into phrases on the basis of their POS tags. There are some standard well-known chunks such as noun phrases, verb phrases, and prepositional phrases.
#
# There are five major categories of phrases : **Noun phrase (NP), Adjective phrase (ADJP), Verb phrase (VP), Prepositional phrase (PP), Adverb phrase (ADVP)**

# %%
from nltk.corpus import conll2000
nltk.download('conll2000')

data = conll2000.chunked_sents()
train_data = data[:10900]
test_data = data[10900:] 

print(len(train_data), len(test_data))
print(train_data[1])
# Out:
# [nltk_data] Downloading package conll2000 to
# [nltk_data]     C:\Users\maria\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\conll2000.zip.
# 10900 48
# (S
#   Chancellor/NNP
#   (PP of/IN)
#   (NP the/DT Exchequer/NNP)
#   (NP Nigel/NNP Lawson/NNP)
#   (NP 's/POS restated/VBN commitment/NN)
#   (PP to/TO)
#   (NP a/DT firm/NN monetary/JJ policy/NN)
#   (VP has/VBZ helped/VBN to/TO prevent/VB)
#   (NP a/DT freefall/NN)
#   (PP in/IN)
#   (NP sterling/NN)
#   (PP over/IN)
#   (NP the/DT past/JJ week/NN)
#   ./.)

# %% [markdown]
# ## 3. Constituency Parsing
#
# Constituent-based grammars are used to analyze and determine the constituents of a sentence. These grammars can be used to model or represent the internal structure of sentences in terms of a hierarchically ordered structure of their constituents. A constituency parser can be built based on such grammars/rules. The grammer has to be defined.
#
# One of the popular Constituency Parsing implementation is from stanford. A **probabilistic context-free grammar parser**
#
# **TODO: Implement an example** <br>
# Parser can be downloaded here : `https://nlp.stanford.edu/software/stanford-parser-4.2.0.zip`
#
# Online tutorial :

# %%
# Download and unzip the parser
# !pip install unzip
# !pip install wget
#!wget https://nlp.stanford.edu/software/stanford-parser-4.2.0.zip
# !unzip stanford-parser-4.2.0.zip
# Out:
# Archive:  stanford-parser-4.2.0.zip
#    creating: stanford-parser-full-2020-11-17/
#   inflating: stanford-parser-full-2020-11-17/ejml-simple-0.38.jar
#   inflating: stanford-parser-full-2020-11-17/StanfordDependenciesManual.pdf
#   inflating: stanford-parser-full-2020-11-17/Makefile
#   inflating: stanford-parser-full-2020-11-17/ShiftReduceDemo.java
#   inflating: stanford-parser-full-2020-11-17/slf4j-api-1.7.12-sources.jar
#   inflating: stanford-parser-full-2020-11-17/ejml-core-0.38.jar
#   inflating: stanford-parser-full-2020-11-17/build.xml
#   inflating: stanford-parser-full-2020-11-17/lexparser-gui.sh
#    creating: stanford-parser-full-2020-11-17/data/
#  extracting: stanford-parser-full-2020-11-17/data/chinese-onesent-unseg-gb18030.txt
#  extracting: stanford-parser-full-2020-11-17/data/arabic-onesent-utf8.txt
#   inflating: stanford-parser-full-2020-11-17/data/chinese-onesent-unseg-utf8.txt
#   inflating: stanford-parser-full-2020-11-17/data/testsent.txt
#   inflating: stanford-parser-full-2020-11-17/data/pos-sentences.txt
#  extracting: stanford-parser-full-2020-11-17/data/chinese-onesent-utf8.txt
#  extracting: stanford-parser-full-2020-11-17/data/chinese-onesent-gb18030.txt
#  extracting: stanford-parser-full-2020-11-17/data/english-onesent.txt
#  extracting: stanford-parser-full-2020-11-17/data/german-onesent.txt
#   inflating: stanford-parser-full-2020-11-17/data/french-onesent.txt
#   inflating: stanford-parser-full-2020-11-17/LICENSE.txt
#   inflating: stanford-parser-full-2020-11-17/stanford-parser-4.2.0-sources.jar
#   inflating: stanford-parser-full-2020-11-17/lexparser-gui.command
#   inflating: stanford-parser-full-2020-11-17/README_dependencies.txt
#   inflating: stanford-parser-full-2020-11-17/ejml-ddense-0.38.jar
#    creating: stanford-parser-full-2020-11-17/conf/
#   inflating: stanford-parser-full-2020-11-17/conf/ftb-latest.conf
#   inflating: stanford-parser-full-2020-11-17/conf/atb-latest.conf
#   inflating: stanford-parser-full-2020-11-17/ejml-ddense-0.39-sources.jar
#   inflating: stanford-parser-full-2020-11-17/ejml-simple-0.39-sources.jar
#   inflating: stanford-parser-full-2020-11-17/README.txt
#   inflating: stanford-parser-full-2020-11-17/slf4j-simple.jar
#   inflating: stanford-parser-full-2020-11-17/lexparser-lang-train-test.sh
#   inflating: stanford-parser-full-2020-11-17/stanford-parser-4.2.0-models.jar
#   inflating: stanford-parser-full-2020-11-17/stanford-parser-4.2.0-javadoc.jar
#   inflating: stanford-parser-full-2020-11-17/lexparser.sh
#   inflating: stanford-parser-full-2020-11-17/lexparser-lang.sh
#   inflating: stanford-parser-full-2020-11-17/lexparser.bat
#   inflating: stanford-parser-full-2020-11-17/ParserDemo2.java
#   inflating: stanford-parser-full-2020-11-17/pom.xml
#   inflating: stanford-parser-full-2020-11-17/ejml-core-0.39-sources.jar
#   inflating: stanford-parser-full-2020-11-17/stanford-parser.jar
#   inflating: stanford-parser-full-2020-11-17/DependencyParserDemo.java
#    creating: stanford-parser-full-2020-11-17/bin/
#   inflating: stanford-parser-full-2020-11-17/bin/makeSerialized.csh
#   inflating: stanford-parser-full-2020-11-17/bin/run-tb-preproc
#   inflating: stanford-parser-full-2020-11-17/slf4j-api.jar
#   inflating: stanford-parser-full-2020-11-17/ParserDemo.java
#   inflating: stanford-parser-full-2020-11-17/lexparser_lang.def
#   inflating: stanford-parser-full-2020-11-17/lexparser-gui.bat

# %%
import nltk, os
from nltk.parse.stanford import StanfordParser

os.environ['CLASSPATH'] = '/content/stanford-parser-full-2020-11-17/*'

scp = StanfordParser('/content/stanford-parser-full-2020-11-17/stanford-parser.jar','/content/stanford-parser-full-2020-11-17/stanford-parser-4.2.0-models.jar')

sentence = "Innopolis University is a university located in the city of Innopolis."

result = list(scp.raw_parse(sentence))
print(result[0])
# Out:
# <ipython-input-8-932a24bd9818>:6: DeprecationWarning: The StanfordParser will be deprecated
# Please use nltk.parse.corenlp.CoreNLPParser instead.
#   scp = StanfordParser('/content/stanford-parser-full-2020-11-17/stanford-parser.jar','/content/stanford-parser-full-2020-11-17/stanford-parser-4.2.0-models.jar')
# (ROOT
#   (S
#     (NP (NNP Innopolis) (NNP University))
#     (VP
#       (VBZ is)
#       (NP
#         (NP (DT a) (NN university))
#         (VP
#           (VBN located)
#           (PP
#             (IN in)
#             (NP
#               (NP (DT the) (NN city))
#               (PP (IN of) (NP (NNP Innopolis))))))))
#     (. .)))

# %%
## To display in colab
# !apt-get install -y xvfb # Install X Virtual Frame Buffer

os.system('Xvfb :1 -screen 0 1600x1200x16  &')    # create virtual display with size 1600x1200 and 16 bit color. Color can be changed to 24 or 8
os.environ['DISPLAY']=':1.0'  

# !apt install ghostscript python3-tk
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-510
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   xvfb
# 0 upgraded, 1 newly installed, 0 to remove and 28 not upgraded.
# Need to get 780 kB of archives.
# After this operation, 2,271 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 xvfb amd64 2:1.20.13-1ubuntu1~20.04.5 [780 kB]
# Fetched 780 kB in 1s (689 kB/s)
# Selecting previously unselected package xvfb.
# (Reading database ... 129501 files and directories currently installed.)
# Preparing to unpack .../xvfb_2%3a1.20.13-1ubuntu1~20.04.5_amd64.deb ...
# Unpacking xvfb (2:1.20.13-1ubuntu1~20.04.5) ...
# Setting up xvfb (2:1.20.13-1ubuntu1~20.04.5) ...
# Processing triggers for man-db (2.9.1-1) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python3-tk is already the newest version (3.8.10-0ubuntu1~20.04).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-510
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   fonts-droid-fallback fonts-noto-mono fonts-urw-base35 libgs9 libgs9-common
#   libidn11 libijs-0.35 libjbig2dec0 poppler-data
# Suggested packages:
#   fonts-noto fonts-freefont-otf | fonts-freefont-ttf fonts-texgyre
#   ghostscript-x poppler-utils fonts-japanese-mincho | fonts-ipafont-mincho
#   fonts-japanese-gothic | fonts-ipafont-gothic fonts-arphic-ukai
#   fonts-arphic-uming fonts-nanum
# The following NEW packages will be installed:
#   fonts-droid-fallback fonts-noto-mono fonts-urw-base35 ghostscript libgs9
#   libgs9-common libidn11 libijs-0.35 libjbig2dec0 poppler-data
# 0 upgraded, 10 newly installed, 0 to remove and 28 not upgraded.
# Need to get 12.7 MB of archives.
# After this operation, 51.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/main amd64 fonts-droid-fallback all 1:6.0.1r16-1.1 [1,805 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/main amd64 poppler-data all 0.4.9-2 [1,475 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 fonts-noto-mono all 20200323-1build1~ubuntu20.04.1 [80.6 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/main amd64 fonts-urw-base35 all 20170801.1-3 [6,333 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgs9-common all 9.50~dfsg-5ubuntu4.6 [681 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal/main amd64 libidn11 amd64 1.33-2.2ubuntu2 [46.2 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal/main amd64 libijs-0.35 amd64 0.35-15 [15.7 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal/main amd64 libjbig2dec0 amd64 0.18-1ubuntu1 [60.0 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libgs9 amd64 9.50~dfsg-5ubuntu4.6 [2,173 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 ghostscript amd64 9.50~dfsg-5ubuntu4.6 [51.8 kB]
# Fetched 12.7 MB in 2s (6,477 kB/s)
# Selecting previously unselected package fonts-droid-fallback.
# (Reading database ... 129508 files and directories currently installed.)
# Preparing to unpack .../0-fonts-droid-fallback_1%3a6.0.1r16-1.1_all.deb ...
# Unpacking fonts-droid-fallback (1:6.0.1r16-1.1) ...
# Selecting previously unselected package poppler-data.
# Preparing to unpack .../1-poppler-data_0.4.9-2_all.deb ...
# Unpacking poppler-data (0.4.9-2) ...
# Selecting previously unselected package fonts-noto-mono.
# Preparing to unpack .../2-fonts-noto-mono_20200323-1build1~ubuntu20.04.1_all.deb ...
# Unpacking fonts-noto-mono (20200323-1build1~ubuntu20.04.1) ...
# Selecting previously unselected package fonts-urw-base35.
# Preparing to unpack .../3-fonts-urw-base35_20170801.1-3_all.deb ...
# Unpacking fonts-urw-base35 (20170801.1-3) ...
# Selecting previously unselected package libgs9-common.
# Preparing to unpack .../4-libgs9-common_9.50~dfsg-5ubuntu4.6_all.deb ...
# Unpacking libgs9-common (9.50~dfsg-5ubuntu4.6) ...
# Selecting previously unselected package libidn11:amd64.
# Preparing to unpack .../5-libidn11_1.33-2.2ubuntu2_amd64.deb ...
# Unpacking libidn11:amd64 (1.33-2.2ubuntu2) ...
# Selecting previously unselected package libijs-0.35:amd64.
# Preparing to unpack .../6-libijs-0.35_0.35-15_amd64.deb ...
# Unpacking libijs-0.35:amd64 (0.35-15) ...
# Selecting previously unselected package libjbig2dec0:amd64.
# Preparing to unpack .../7-libjbig2dec0_0.18-1ubuntu1_amd64.deb ...
# Unpacking libjbig2dec0:amd64 (0.18-1ubuntu1) ...
# Selecting previously unselected package libgs9:amd64.
# Preparing to unpack .../8-libgs9_9.50~dfsg-5ubuntu4.6_amd64.deb ...
# Unpacking libgs9:amd64 (9.50~dfsg-5ubuntu4.6) ...
# Selecting previously unselected package ghostscript.
# Preparing to unpack .../9-ghostscript_9.50~dfsg-5ubuntu4.6_amd64.deb ...
# Unpacking ghostscript (9.50~dfsg-5ubuntu4.6) ...
# Setting up fonts-noto-mono (20200323-1build1~ubuntu20.04.1) ...
# Setting up libijs-0.35:amd64 (0.35-15) ...
# Setting up fonts-urw-base35 (20170801.1-3) ...
# Setting up poppler-data (0.4.9-2) ...
# Setting up libjbig2dec0:amd64 (0.18-1ubuntu1) ...
# Setting up libidn11:amd64 (1.33-2.2ubuntu2) ...
# Setting up fonts-droid-fallback (1:6.0.1r16-1.1) ...
# Setting up libgs9-common (9.50~dfsg-5ubuntu4.6) ...
# Setting up libgs9:amd64 (9.50~dfsg-5ubuntu4.6) ...
# Setting up ghostscript (9.50~dfsg-5ubuntu4.6) ...
# Processing triggers for fontconfig (2.13.1-2ubuntu3) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Processing triggers for man-db (2.9.1-1) ...

# %% [markdown]
# For the tags meanings [see](https://web.archive.org/web/20130517134339/http://bulba.sdsu.edu/jeanette/thesis/PennTags.html)

# %%
from IPython.display import display
display(result[0])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /usr/local/lib/python3.8/dist-packages/nltk/tree/tree.py in _repr_svg_(self)
#     781
#     782     def _repr_svg_(self):
# --> 783         from svgling import draw_tree
#     784
#     785         return draw_tree(self)._repr_svg_()
#
# ModuleNotFoundError: No module named 'svgling'
# Tree('ROOT', [Tree('S', [Tree('NP', [Tree('NNP', ['Innopolis']), Tree('NNP', ['University'])]), Tree('VP', [Tree('VBZ', ['is']), Tree('NP', [Tree('NP', [Tree('DT', ['a']), Tree('NN', ['university'])]), Tree('VP', [Tree('VBN', ['located']), Tree('PP', [Tree('IN', ['in']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['city'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NNP', ['Innopolis'])])])])])])])]), Tree('.', ['.'])])])

# %% [markdown]
# ### 3.1 Try it on your sentence

# %% [markdown]
# ## 4. Dependency Parsing
#
# In dependency parsing, we try to use dependency-based grammars to analyze and infer both structure and semantic dependencies and relationships between tokens in a sentence.
#
# ![](https://files.realpython.com/media/displacy_dependency_parse.de72f9b1d115.png)
#
# Dependency Parsing used in shallow parsing and named entity recognition

# %%
import spacy
import nltk

nlp = spacy.load("en_core_web_sm")

sentence_nlp = nlp("US unvails world's most powerful supercomputer, beats China")
sentence_nlp = nlp("Innopolis University is a university located in the city of Innopolis.")

# %%
from spacy import displacy

displacy.render(sentence_nlp, jupyter=True, 
                options={'distance': 110,
                         'arrow_stroke': 2,
                         'arrow_width': 8})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="cb6d858d02da439d8d80cc3c7095d533-0" class="displacy" width="1260" height="247.0" direction="ltr" style="max-width: none; height: 247.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="157.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Innopolis</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="157.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">University</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="157.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="157.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="157.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">university</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="157.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">located</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="157.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="157.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="157.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">city</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="157.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="157.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">Innopolis.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cb6d858d02da439d8d80cc3c7095d533-0-0" stroke-width="2px" d="M70,112.0 C70,57.0 155.0,57.0 155.0,112.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cb6d858d02da439d8d80cc3c7095d533-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,114.0 L64,104.0 76,104.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cb6d858d02da439d8d80cc3c7095d533-0-1" stroke-width="2px" d="M180,112.0 C180,57.0 265.0,57.0 265.0,112.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cb6d858d02da439d8d80cc3c7095d533-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M180,114.0 L174,104.0 186,104.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cb6d858d02da439d8d80cc3c7095d533-0-2" stroke-width="2px" d="M400,112.0 C400,57.0 485.0,57.0 485.0,112.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cb6d858d02da439d8d80cc3c7095d533-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400,114.0 L394,104.0 406,104.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cb6d858d02da439d8d80cc3c7095d533-0-3" stroke-width="2px" d="M290,112.0 C290,2.0 490.0,2.0 490.0,112.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cb6d858d02da439d8d80cc3c7095d533-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M490.0,114.0 L496.0,104.0 484.0,104.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cb6d858d02da439d8d80cc3c7095d533-0-4" stroke-width="2px" d="M510,112.0 C510,57.0 595.0,57.0 595.0,112.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cb6d858d02da439d8d80cc3c7095d533-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">acl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595.0,114.0 L601.0,104.0 589.0,104.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cb6d858d02da439d8d80cc3c7095d533-0-5" stroke-width="2px" d="M620,112.0 C620,57.0 705.0,57.0 705.0,112.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cb6d858d02da439d8d80cc3c7095d533-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M705.0,114.0 L711.0,104.0 699.0,104.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cb6d858d02da439d8d80cc3c7095d533-0-6" stroke-width="2px" d="M840,112.0 C840,57.0 925.0,57.0 925.0,112.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cb6d858d02da439d8d80cc3c7095d533-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M840,114.0 L834,104.0 846,104.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cb6d858d02da439d8d80cc3c7095d533-0-7" stroke-width="2px" d="M730,112.0 C730,2.0 930.0,2.0 930.0,112.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cb6d858d02da439d8d80cc3c7095d533-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M930.0,114.0 L936.0,104.0 924.0,104.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cb6d858d02da439d8d80cc3c7095d533-0-8" stroke-width="2px" d="M950,112.0 C950,57.0 1035.0,57.0 1035.0,112.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#

# %% [markdown]
# ### 4.1 Try it on your sentence

# %%
sentence_nlp = nlp("This is a totally random sentence and most probably has a wrong grammer. I am way too hungry to exist")

displacy.render(sentence_nlp, jupyter=True, 
                options={'distance': 110,
                         'arrow_stroke': 2,
                         'arrow_width': 8})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="865a46928b6d4482b6f692a097559eae-0" class="displacy" width="2250" height="412.0" direction="ltr" style="max-width: none; height: 412.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">This</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">totally</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">random</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">sentence</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">most</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">probably</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1260">wrong</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1260">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">grammer.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1480">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1480">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1590">am</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1590">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">way</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1810">too</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1810">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="1920">hungry</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1920">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="322.0">
#     <tspan class="displacy-word" fill="currentColor" x="2140">exist</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2140">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-865a46928b6d4482b6f692a097559eae-0-0" stroke-width="2px" d="M70,277.0 C70,222.0 140.0,222.0 140.0,277.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-865a46928b6d4482b6f692a097559eae-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,279.0 L64,269.0 76,269.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-865a46928b6d4482b6f692a097559eae-0-1" stroke-width="2px" d="M290,277.0 C290,167.0 585.0,167.0 585.0,277.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-865a46928b6d4482b6f692a097559eae-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M290,279.0 L284,269.0 296,269.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-865a46928b6d4482b6f692a097559eae-0-2" stroke-width="2px" d="M400,277.0 C400,222.0 470.0,222.0 470.0,277.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-865a46928b6d4482b6f692a097559eae-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400,279.0 L394,269.0 406,269.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-865a46928b6d4482b6f692a097559eae-0-3" stroke-width="2px" d="M510,277.0 C510,222.0 580.0,222.0 580.0,277.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-865a46928b6d4482b6f692a097559eae-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M510,279.0 L504,269.0 516,269.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-865a46928b6d4482b6f692a097559eae-0-4" stroke-width="2px" d="M180,277.0 C180,112.0 590.0,112.0 590.0,277.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-865a46928b6d4482b6f692a097559eae-0-4" class="displacy-label" startOffset="50%" side="left" fill="curr

# %% [markdown]
# ## 5. Named Entity Recognition
#
# Named Entity Recognition (NER) is the process of locating named entities in unstructured text and then classifying them into pre-defined categories, such as person names, organizations, locations, monetary values, percentages, time expressions, and so on.

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from nltk.chunk import ne_chunk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %% [markdown]
# ## 5.1 Get data

# %%
sentence = 'European authorities fined Google a record $5.1 billion on Wednesday for abusing its power in the mobile phone market and ordered the company to alter its practices'

# %% [markdown]
# ## Preprocess the data

# %%
def preprocess(sent):
  sent = nltk.word_tokenize(sent)
  sent = nltk.pos_tag(sent)
  return sent

sent = preprocess(sentence)
sent
# Out:
# [('European', 'JJ'),
#  ('authorities', 'NNS'),
#  ('fined', 'VBD'),
#  ('Google', 'NNP'),
#  ('a', 'DT'),
#  ('record', 'NN'),
#  ('$', '$'),
#  ('5.1', 'CD'),
#  ('billion', 'CD'),
#  ('on', 'IN'),
#  ('Wednesday', 'NNP'),
#  ('for', 'IN'),
#  ('abusing', 'VBG'),
#  ('its', 'PRP$'),
#  ('power', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('mobile', 'JJ'),
#  ('phone', 'NN'),
#  ('market', 'NN'),
#  ('and', 'CC'),
#  ('ordered', 'VBD'),
#  ('the', 'DT'),
#  ('company', 'NN'),
#  ('to', 'TO'),
#  ('alter', 'VB'),
#  ('its', 'PRP$'),
#  ('practices', 'NNS')]

# %% [markdown]
# ## Define pattern to parse the data

# %%
pattern = 'NP: {<DT>?<JJ>*<NN>}'

cp = nltk.RegexpParser(pattern)
cs = cp.parse(sent)
print(cs)
# Out:
# (S
#   European/JJ
#   authorities/NNS
#   fined/VBD
#   Google/NNP
#   (NP a/DT record/NN)
#   $/$
#   5.1/CD
#   billion/CD
#   on/IN
#   Wednesday/NNP
#   for/IN
#   abusing/VBG
#   its/PRP$
#   (NP power/NN)
#   in/IN
#   (NP the/DT mobile/JJ phone/NN)
#   (NP market/NN)
#   and/CC
#   ordered/VBD
#   (NP the/DT company/NN)
#   to/TO
#   alter/VB
#   its/PRP$
#   practices/NNS)

# %% [markdown]
# ## Parse data and visualize

# %%
NPChunker = nltk.RegexpParser(pattern) 
result = NPChunker.parse(sent)

# %%
from nltk.chunk import conlltags2tree, tree2conlltags
from pprint import pprint

iob_tagged = tree2conlltags(cs)
pprint(iob_tagged)
# Out:
# [('European', 'JJ', 'O'),
#  ('authorities', 'NNS', 'O'),
#  ('fined', 'VBD', 'O'),
#  ('Google', 'NNP', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('record', 'NN', 'I-NP'),
#  ('$', '$', 'O'),
#  ('5.1', 'CD', 'O'),
#  ('billion', 'CD', 'O'),
#  ('on', 'IN', 'O'),
#  ('Wednesday', 'NNP', 'O'),
#  ('for', 'IN', 'O'),
#  ('abusing', 'VBG', 'O'),
#  ('its', 'PRP$', 'O'),
#  ('power', 'NN', 'B-NP'),
#  ('in', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('mobile', 'JJ', 'I-NP'),
#  ('phone', 'NN', 'I-NP'),
#  ('market', 'NN', 'B-NP'),
#  ('and', 'CC', 'O'),
#  ('ordered', 'VBD', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('company', 'NN', 'I-NP'),
#  ('to', 'TO', 'O'),
#  ('alter', 'VB', 'O'),
#  ('its', 'PRP$', 'O'),
#  ('practices', 'NNS', 'O')]

# %% [markdown]
# ## NER with spacy
#
# SpaCy’s named entity recognition has been trained on the OntoNotes 5 corpus

# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm

# %% [markdown]
# ## Get data
#
# **en_core_web_sm** : English pipeline optimized for CPU. Components: tok2vec, tagger, parser, senter, ner, attribute_ruler, lemmatizer

# %%
nlp = en_core_web_sm.load()
doc = nlp('European authorities fined Google a record $5.1 billion on Wednesday for abusing its power in the mobile phone market and ordered the company to alter its practices')
pprint([(X.text, X.label_) for X in doc.ents])
# Out:
# [('European', 'NORP'),
#  ('Google', 'ORG'),
#  ('$5.1 billion', 'MONEY'),
#  ('Wednesday', 'DATE')]

# %%
doc.text
# Out:
# 'European authorities fined Google a record $5.1 billion on Wednesday for abusing its power in the mobile phone market and ordered the company to alter its practices'

# %% [markdown]
# ## TASK
#
# 1. Using Python libraries, download Wikipedia's page on topic of your choice and apply NER (using NLTK and spacy).
# 1. Compare the results and visualize one paragraph with with entities assigned to words (you can try spacy visualization tool [`displacy`](https://spacy.io/usage/visualizers))

# %%
# downloading a random wiki page
# based on https://wikipedia-api.readthedocs.io/en/latest/README.html?badge=latest
import wikipediaapi
wiki_wiki = wikipediaapi.Wikipedia('en')
page_py = wiki_wiki.page('Barack_Obama')

text = page_py.text

#loading model from spacy
nlp = en_core_web_sm.load()

#using model on the text gotten from wikipidia 
doc = nlp(text)

# visuilizing with displacy 
displacy.render(doc, jupyter=True,style="ent", 
                options={'distance': 110,
                         'arrow_stroke': 2,
                         'arrow_width': 8})
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Barack Hussein Obama II
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  ( (listen) bə-RAHK hoo-SAYN oh-BAH-mə; born
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     August 4, 1961
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ) is an
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  retired politician who served as the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     44th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  president of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  from
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2009
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  to
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Obama
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , a member of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Democratic Party
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , was the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     African-American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#   president of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . He previously served as a
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  senator from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Illinois
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  from
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2005
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  to
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2008
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and as an
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Illinois
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  state senator from
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1997 to 2004
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , and previously worked as a civil rights lawyer before entering politics. </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Obama
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  was born in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Honolulu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hawaii
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . After graduating from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Columbia University
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1983
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , he worked as a community organizer in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chicago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1988
#     <span style="font-size: 0.8em; font-weight: bold;

# %%
# NER but using NLTK
# based on https://towardsdatascience.com/named-entity-recognition-with-nltk-and-spacy-8c4a7d88e7da
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from nltk.chunk import conlltags2tree, tree2conlltags
from pprint import pprint

#tokenizing and pos
# def preprocess(sent):
#     sent = nltk.word_tokenize(sent)
#     sent = nltk.pos_tag(sent)
#     return sent

# sent = preprocess(text)

# #parsing
# pattern = 'NP: {<DT>?<JJ>*<NN>}'
# cp = nltk.RegexpParser(pattern)
# cs = cp.parse(sent)

ne_tree = ne_chunk(pos_tag(word_tokenize(text)))
print(ne_tree)
# Out:
# (S
#   (PERSON Barack/NNP)
#   (PERSON Hussein/NNP Obama/NNP II/NNP)
#   (/(
#   (/(
#   listen/VBN
#   )/)
#   bə-RAHK/JJ
#   hoo-SAYN/JJ
#   oh-BAH-mə/NN
#   ;/:
#   born/VBN
#   August/NNP
#   4/CD
#   ,/,
#   1961/CD
#   )/)
#   is/VBZ
#   an/DT
#   (GPE American/JJ)
#   retired/JJ
#   politician/NN
#   who/WP
#   served/VBD
#   as/IN
#   the/DT
#   44th/CD
#   president/NN
#   of/IN
#   the/DT
#   (GPE United/NNP States/NNPS)
#   from/IN
#   2009/CD
#   to/TO
#   2017/CD
#   ./.
#   (PERSON Obama/NNP)
#   ,/,
#   a/DT
#   member/NN
#   of/IN
#   the/DT
#   (ORGANIZATION Democratic/NNP Party/NNP)
#   ,/,
#   was/VBD
#   the/DT
#   first/JJ
#   African-American/JJ
#   president/NN
#   of/IN
#   the/DT
#   (GPE United/NNP States/NNPS)
#   ./.
#   He/PRP
#   previously/RB
#   served/VBD
#   as/IN
#   a/DT
#   (GPE U.S./NNP)
#   senator/NN
#   from/IN
#   (GPE Illinois/NNP)
#   from/IN
#   2005/CD
#   to/TO
#   2008/CD
#   and/CC
#   as/IN
#   an/DT
#   Illinois/NNP
#   state/NN
#   senator/NN
#   from/IN
#   1997/CD
#   to/TO
#   2004/CD
#   ,/,
#   and/CC
#   previously/RB
#   worked/VBN
#   as/IN
#   a/DT
#   civil/JJ
#   rights/NNS
#   lawyer/NN
#   before/IN
#   entering/VBG
#   politics/NNS
#   ./.
#   (PERSON Obama/NNP)
#   was/VBD
#   born/VBN
#   in/IN
#   (GPE Honolulu/NNP)
#   ,/,
#   (GPE Hawaii/NNP)
#   ./.
#   After/IN
#   graduating/VBG
#   from/IN
#   (ORGANIZATION Columbia/NNP University/NNP)
#   in/IN
#   1983/CD
#   ,/,
#   he/PRP
#   worked/VBD
#   as/IN
#   a/DT
#   community/NN
#   organizer/NN
#   in/IN
#   (GPE Chicago/NNP)
#   ./.
#   In/IN
#   1988/CD
#   ,/,
#   he/PRP
#   enrolled/VBD
#   in/IN
#   (ORGANIZATION Harvard/NNP Law/NNP School/NNP)
#   ,/,
#   where/WRB
#   he/PRP
#   was/VBD
#   the/DT
#   first/JJ
#   black/JJ
#   president/NN
#   of/IN
#   the/DT
#   (ORGANIZATION Harvard/NNP Law/NNP Review/NNP)
#   ./.
#   After/IN
#   graduating/VBG
#   ,/,
#   he/PRP
#   became/VBD
#   a/DT
#   civil/JJ
#   rights/NNS
#   attorney/NN
#   and/CC
#   an/DT
#   academic/JJ
#   ,/,
#   teaching/VBG
#   constitutional/JJ
#   law/NN
#   at/IN
#   the/DT
#   (ORGANIZATION University/NNP)
#   of/IN
#   (GPE Chicago/NNP)
#   Law/NNP
#   School/NNP
#   from/IN
#   1992/CD
#   to/TO
#   2004/CD
#   ./.
#   Turning/VBG
#   to/TO
#   elective/JJ
#   politics/NNS
#   ,/,
#   he/PRP
#   represented/VBD
#   the/DT
#   13th/JJ
#   district/NN
#   in/IN
#   the/DT
#   (ORGANIZATION Illinois/NNP)
#   Senate/NNP
#   from/IN
#   1997/CD
#   until/IN
#   2004/CD
#   ,/,
#   when/WRB
#   he/PRP
#   ran/VBD
#   for/IN
#   the/DT
#   (GPE U.S./NNP)
#   (ORGANIZATION Senate/NNP)
#   ./.
#   (PERSON Obama/NNP)
#   received/VBD
#   national/JJ
#   attention/NN
#   in/IN
#   2004/CD
#   with/IN
#   his/PRP$
#   March/NNP
#   Senate/NNP
#   primary/JJ
#   win/NN
#   ,/,
#   his/PRP$
#   well-received/JJ
#   keynote/NN
#   address/NN
#   at/IN
#   the/DT
#   July/NNP
#   (ORGANIZATION Democratic/JJ National/NNP Convention/NNP)
#   ,/,
#   and/CC
#   his/PRP$
#   landslide/JJ
#   November/NNP
#   election/NN
#   to/TO
#   the/DT
#   (ORGANIZATION Senate/NNP)
#   ./.
#   In/IN
#   2008/CD
#   ,/,
#   after/IN
#   a/DT
#   close/JJ
#   primary/JJ
#   campaign/NN
#   against/IN
#   (PERSON Hillary/NNP Clinton/NNP)
#   ,/,
#   he/PRP
#   was/VBD
#   nominated/VBN
#   by/IN
#   the/DT
#   (ORGANIZATION Democratic/NNP Party/NNP)
#   for/IN
#   president/NN
#   and/CC
#   chose/VBD
#   (PERSON Joe/NNP Biden/NNP)
#   as/IN
#   his/PRP$
#   running/VBG
#   mate/NN
#   ./.
#   (PERSON Obama/NNP)
#   was/VBD
#   elected/VBN
#   over/IN
#   (ORGANIZATION Republican/JJ)
#   nominee/NN
#   (PERSON John/NNP McCain/NNP)
#   in/IN
#   the/DT
#   presidential/JJ
#   election/NN
#   and/CC
#   was/VBD
#   inaugurated/VBN
#   on/IN
#   January/NNP
#   20/CD
#   ,/,
#   2009/CD
#   ./.
#   Nine/CD
#   months/NNS
#   later/RB
#   ,/,
#   he/PRP
#   was/VBD
#   named/VBN
#   the/DT
#   2009/CD
#   Nobel/NNP
#   Peace/NNP
#   Prize/NNP
#   laureate/NN
#   ,/,
#   a/DT
#   decision/NN
#   that/WDT
#   drew/VBD
#   a/DT
#   mixture/NN
#   of/IN
#   praise/NN
#   and/CC
#   criticism/NN
#   ./.
#   (PERSON Obama/NNP)
#   's/POS
#   first-term/JJ
#   actions/NNS
#   addressed/VBD
#   the/DT
#   global/JJ
#   financial/JJ
#   crisis/NN
#   and/CC
#   included/VBD
#   a/DT
#   major/JJ
#   stimulus/NN
#   package/NN
#   ,/,
#   a/DT
#   partial/JJ
#   extension/NN
#   of/IN
#   (PERSON George/NNP W./NNP Bush/NNP)
#   's/POS
#   tax/NN
#   cuts/NNS
#   ,/,
#   legislation/NN
#   to/TO
#   reform/VB
#   health/NN
#   care/NN
#   ,/,
#   a/DT
#   major/JJ
#   financial/JJ
#   regulation/NN
#   reform/NN
#   bill/NN
#   ,/,
#   and/CC
#   the/DT
#   end/NN
#   of/IN
#   a/DT
#   major/JJ
#   (ORGANIZATION US/NNP)
#   military/JJ
#   presence/NN
#   in/IN
#   (GPE Iraq/NNP)
#   ./.
#   (PERSON Obama/NNP)
#   also/RB
#   appointed/VBD
#   (ORGANIZATION Supreme/NNP Court/NNP)
#   justices/VBZ
#   (PERSON Sonia/NNP Sotomayor/NNP)
#   and/CC
#   (PERSON Elena/NNP Kagan/NNP)
#   ,/,
#   the/DT
#   former/JJ
#   being/VBG
#   the/DT
#   first/JJ
#   Hispanic/JJ
#   (GPE American/JJ)
#   on/IN
#   the/DT
#   (ORGANIZATION Supreme/NNP Court/NNP)
#   ./.
#   He/PRP
#   ordered/VBD
#   the/DT
#   counterterrorism/NN
#   raid/VBD
#   which/WDT
#   killed/VBD
#   (PERSON Osama/NNP)
#   bin/NN
#   (PERSON Laden/NNP)
#   and/CC
#   downplayed/VBD
#   (PERSON Bush/NNP)
#   's/POS
#   counterinsurgency/NN
#   model/NN
#   ,/,
#   expanding/VBG
#   air/NN
#   strikes/NNS
#   and/CC
#   making/VBG
#   extensive/JJ
#   use/NN
#   of/IN
#   special/JJ
#   forces/NNS
#   while/IN
#   encouraging/VBG
#   greater/JJR
#   reliance/NN
#   on/IN
#   host-government/JJ
#   militaries/NNS
#   ./.
#   After/IN
#   winning/VBG
#   re-election/NN
#   by/IN
#   defeating/VBG
#   (ORGANIZATION Republican/JJ)
#   opponent/NN
#   (PERSON Mitt/NNP Romney/NNP)
#   ,/,
#   (PERSON Obama/NNP)
#   was/VBD
#   sworn/VBN
#   in/IN
#   for/IN
#   a/DT
#   second/JJ
#   term/NN
#   on/IN
#   January/NNP
#   20/CD
#   ,/,
#   2013/CD
#   ./.
#   In/IN
#   his/PRP$
#   second/JJ
#   term/NN
#   ,/,
#   (PERSON Obama/NNP)
#   took/VBD
#   steps/NNS
#   to/TO
#   combat/VB
#   climate/NN
#   change/NN
#   ,/,
#   signing/VBG
#   a/DT
#   major/JJ
#   international/JJ
#   climate/NN
#   agreement/NN
#   and/CC
#   an/DT
#   executive/NN
#   order/NN
#   to/TO
#   limit/VB
#   carbon/NN
#   emissions/NNS
#   ./.
#   (PERSON Obama/NNP)
#   also/RB
#   presided/VBD
#   over/IN
#   the/DT
#   implementation/NN
#   of/IN
#   the/DT
#   (ORGANIZATION Affordable/NNP Care/NNP Act/NNP)
#   and/CC
#   other/JJ
#   legislation/NN
#   passed/VBN
#   in/IN
#   his/PRP$
#   first/JJ
#   term/NN
#   ,/,
#   and/CC
#   he/PRP
#   negotiated/VBD
#   a/DT
#   nuclear/JJ
#   agreement/NN
#   with/IN
#   (GPE Iran/NNP)
#   and/CC
#   normalized/JJ
#   relations/NNS
#   with/IN
#   (GPE Cuba/NNP)
#   ./.
#   The/DT
#   number/NN
#   of/IN
#   (GPE American/JJ)
#   soldiers/NNS
#   in/IN
#   (GPE Afghanistan/NNP)
#   fell/VBD
#   dramatically/RB
#   during/IN
#   (PERSON Obama/NNP)
#   's/POS
#   second/JJ
#   term/NN
#   ,/,
#   though/IN
#   (GPE U.S./NNP)
#   soldiers/NNS
#   remained/VBD
#   in/IN
#   (GPE Afghanistan/NNP)
#   throughout/IN
#   (PERSON Obama/NNP)
#   's/POS
#   presidency/NN
#   ./.
#   During/IN
#   (PERSON Obama/NNP)
#   's/POS
#   terms/NNS
#   as/IN
#   president/NN
#   ,/,
#   the/DT
#   (GPE United/NNP States/NNPS)
#   '/POS
#   reputation/NN
#   abroad/RB
#   and/CC
#   the/DT
#   (GPE American/JJ)
#   economy/NN
#   improved/VBD
#   significantly/RB
#   ,/,
#   although/IN
#   the/DT
#   country/NN
#   experienced/VBD
#   high/JJ
#   levels/NNS
#   of/IN
#   partisan/JJ
#   divide/NN
#   ./.
#   (PERSON Obama/NNP)
#   left/VBD
#   office/NN
#   on/IN
#   January/NNP
#   20/CD
#   ,/,
#   2017/CD
#   ,/,
#   and/CC
#   continues/VBZ
#   to/TO
#   reside/VB
#   in/IN
#   (GPE Washington/NNP)
#   ,/,
#   D.C./NNP
#   His/PRP$
#   presidential/JJ
#   library/NN
#   in/IN
#   (GPE Chicago/NNP)
#   began/VBD
#   construction/NN
#   in/IN
#   2021/CD
#   ./.
#   Since/IN
#   leaving/VBG
#   office/NN
#   ,/,
#   (PERSON Obama/NNP)
#   has/VBZ
#   remained/VBN
#   active/JJ
#   in/IN
#   (ORGANIZATION Democratic/JJ)
#   politics/NNS
#   ,/,
#   including/VBG
#   campaigning/VBG
#   for/IN
#   candidates/NNS
#   in/IN
#   various/JJ
#   (GPE American/JJ)
#   elections/NNS
#   ./.
#   Outside/IN
#   of/IN
#   politics/NNS
#   ,/,
#   (PERSON Obama/NNP)
#   has/VBZ
#   published/VBN
#   three/CD
#   bestselling/VBG
#   books/NNS
#   :/:
#   Dreams/NN
#   from/IN
#   My/PRP$
#   Father/NNP
#   (/(
#   1995/CD
#   )/)
#   ,/,
#   The/DT
#   (ORGANIZATION Audacity/NNP)
#   of/IN
#   (GPE Hope/NNP)
#   (/(
#   2006/CD
#   )/)
#   and/CC
#   A/DT
#   Promised/JJ
#   (GPE Land/NNP)
#   (/(
#   2020/CD
#   )/)
#   ./.
#   Rankings/VBN
#   by/IN
#   scholars/NNS
#   and/CC
#   historians/NNS
#   ,/,
#   in/IN
#   which/WDT
#   he/PRP
#   has/VBZ
#   been/VBN
#   featured/VBN
#   since/IN
#   2010/CD
#   ,/,
#   place/NN
#   him/PRP
#   in/IN
#   the/DT
#   middle/NN
#   to/TO
#   upper/JJ
#   tier/NN
#   of/IN
#   (GPE American/JJ)
#   presidents/NNS
#   ./.
#   Early/JJ
#   life/NN
#   and/CC
#   career/NN
#   (PERSON Obama/NNP)
#   was/VBD
#   born/VBN
#   on/IN
#   August/NNP
#   4/CD
#   ,/,
#   1961/CD
#   ,/,
#   at/IN
#   (ORGANIZATION Kapiolani/NNP Medical/NNP Center/NNP)
#   for/IN
#   (PERSON Women/NNP)
#   and/CC
#   (GPE Children/NNP)
#   in/IN
#   (GPE Honolulu/NNP)
#   ,/,
#   (GPE Hawaii/NNP)
#   ./.
#   He/PRP
#   is/VBZ
#   the/DT
#   only/JJ
#   president/NN
#   born/VBN
#   outside/IN
#   the/DT
#   contiguous/JJ
#   48/CD
#   states/NNS
#   ./.
#   He/PRP
#   was/VBD
#   born/VBN
#   to/TO
#   an/DT
#   (GPE American/JJ)
#   mother/NN
#   and/CC
#   a/DT
#   (GPE Kenyan/NNP)
#   father/NN
#   ./.
#   His/PRP$
#   mother/NN
#   ,/,
#   (PERSON Ann/NNP Dunham/NNP)
#   (/(
#   1942–1995/CD
#   )/)
#   ,/,
#   was/VBD
#   born/VBN
#   in/IN
#   (GPE Wichita/NNP)
#   ,/,
#   (PERSON Kansas/NNP)
#   and/CC
#   was/VBD
#   mostly/RB
#   of/IN
#   (GPE English/NNP)
#   descent/NN
#   ,/,
#   though/IN
#   in/IN
#   2007/CD
#   it/PRP
#   was/VBD
#   discovered/VBN
#   her/PRP$
#   great-great-grandfather/JJ
#   (ORGANIZATION Falmouth/NNP Kearney/NNP)
#   emigrated/VBD
#   from/IN
#   the/DT
#   village/NN
#   of/IN
#   (GPE Moneygall/NNP)
#   ,/,
#   (GPE Ireland/NNP)
#   to/TO
#   the/DT
#   (ORGANIZATION US/NNP)
#   in/IN
#   1850/CD
#   ./.
#   In/IN
#   July/NNP
#   2012/CD
#   ,/,
#   Ancestry.com/NNP
#   found/VBD
#   a/DT
#   strong/JJ
#   likelihood/NN
#   that/IN
#   (PERSON Dunham/NNP)
#   was/VBD
#   descended/VBN
#   from/IN
#   (PERSON John/NNP Punch/NNP)
#   ,/,
#   an/DT
#   enslaved/JJ
#   (GPE African/JJ)
#   man/NN
#   who/WP
#   lived/VBD
#   in/IN
#   the/DT
#   (ORGANIZATION Colony/NNP)
#   of/IN
#   (GPE Virginia/NNP)
#   during/IN
#   the/DT
#   seventeenth/JJ
#   century/NN
#   ./.
#   (PERSON Obama/NNP)
#   's/POS
#   father/NN
#   ,/,
#   (PERSON Barack/NNP Obama/NNP)
#   Sr./NNP
#   (/(
#   1934–1982/CD
#   )/)
#   ,/,
#   was/VBD
#   a/DT
#   married/JJ
#   Luo/NNP
#   Kenyan/NNP
#   from/IN
#   Nyang'oma/NNP
#   Kogelo/NNP
#   ./.
#   (PERSON Obama/NNP)
#   's/POS
#   parents/NNS
#   met/VBD
#   in/IN
#   1960/CD
#   in/IN
#   a/DT
#   (GPE Russian/JJ)
#   language/NN
#   class/NN
#   at/IN
#   the/DT
#   (ORGANIZATION University/NNP)
#   of/IN
#   (GPE Hawaii/NNP)
#   at/IN
#   (GSP Manoa/NNP)
#   ,/,
#   where/WRB
#   his/PRP$
#   father/NN
#   was/VBD
#   a/DT
#   foreign/JJ
#   student/NN
#   on/IN
#   a/DT
#   scholarship/NN
#   ./.
#   The/DT
#   couple/NN
#   married/VBD
#   in/IN
#   (GPE Wailuku/NNP)
#   ,/,
#   (GPE Hawaii/NNP)
#   ,/,
#   on/IN
#   February/NNP
#   2/CD
#   ,/,
#   1961/CD
#   ,/,
#   six/CD
#   months/NNS
#   before/IN
#   (PERSON Obama/NNP)
#   was/VBD
#   born.In/VBN
#   late/RB
#   August/NNP
#   1961/CD
#   ,/,
#   a/DT
#   few/JJ
#   weeks/NNS
#   after/IN
#   he/PRP
#   was/VBD
#   born/VBN
#   ,/,
#   (PERSON Barack/NNP)
#   and/CC
#   his/PRP$
#   mother/NN
#   moved/VBD
#   to/TO
#   the/DT
#   (ORGANIZATION University/NNP)
#   of/IN
#   (GPE Washington/NNP)
#   in/IN
#   (GPE Seattle/NNP)
#   ,/,
#   where/WRB
#   they/PRP
#   lived/VBD
#   for/IN
#   a/DT
#   year/NN
#   ./.
#   During/IN
#   that/DT
#   time/NN
#   ,/,
#   (PERSON Barack/NNP)
#   's/POS
#   father/NN
#   completed/VBD
#   his/PRP$
#   undergraduate/JJ
#   degree/NN
#   in/IN
#   economics/NNS
#   in/IN
#   (GPE Hawaii/NNP)
#   ,/,
#   graduating/VBG
#   in/IN
#   June/NNP
#   1962/CD
#   ./.
#   He/PRP
#   left/VBD
#   to/TO
#   attend/VB
#   graduate/JJ
#   school/NN
#   on/IN
#   a/DT
#   scholarship/NN
#   at/IN
#   (ORGANIZATION Harvard/NNP University/NNP)
#   ,/,
#   where/WRB
#   he/PRP
#   earned/VBD
#   an/DT
#   M.A/NNP
#   ./.
#   in/IN
#   economics/NNS
#   ./.
#   (PERSON Obama/NNP)
#   's/POS
#   parents/NNS
#   divorced/VBN
#   in/IN
#   March/NNP
#   1964/CD
#   ./.
#   (PERSON Obama/NNP Sr./NNP)
#   returned/VBD
#   to/TO
#   (GPE Kenya/NNP)
#   in/IN
#   1964/CD
#   ,/,
#   where/WRB
#   he/PRP
#   married/VBD
#   for/IN
#   a/DT
#   third/JJ
#   time/NN
#   and/CC
#   worked/VBD
#   for/IN
#   the/DT
#   (GPE Kenyan/NNP)
#   government/NN
#   as/IN
#   the/DT
#   (ORGANIZATION Senior/NNP Economic/NNP Analyst/NNP)
#   in/IN
#   the/DT
#   (ORGANIZATION Ministry/NNP)
#   of/IN
#   (GPE Finance/NNP)
#   ./.
#   He/PRP
#   visited/VBD
#   his/PRP$
#   son/NN
#   in/IN
#   (GPE Hawaii/NNP)
#   only/RB
#   once/RB
#   ,/,
#   at/IN
#   (ORGANIZATION Christmas/NNP)
#   1971/CD
#   ,/,
#   before/IN
#   he/PRP
#   was/VBD
#   killed/VBN
#   in/IN
#   an/DT
#   automobile/NN
#   accident/NN
#   in/IN
#   1982/CD
#   ,/,
#   when/WRB
#   (PERSON Obama/NNP)
#   was/VBD
#   21/CD
#   years/NNS
#   old/JJ
#   ./.
#   Recalling/VBG
#   his/PRP$
#   early/JJ
#   childhood/NN
#   ,/,
#   (PERSON Obama/NNP)
#   said/VBD
#   :/:
#   ``/``
#   That/DT
#   my/PRP$
#   father/NN
#   looked/VBD
#   nothing/NN
#   like/IN
#   the/DT
#   people/NNS
#   around/IN
#   me—that/IN
#   he/PRP
#   was/VBD
#   black/JJ
#   as/IN
#   pitch/NN
#   ,/,
#   my/PRP$
#   mother/JJ
#   white/JJ
#   as/IN
#   milk—barely/RB
#   registered/VBN
#   in/IN
#   my/PRP$
#   mind/NN
#   ./.
#   ''/''
#   He/PRP
#   described/VBD
#   his/PRP$
#   struggles/NNS
#   as/IN
#   a/DT
#   young/JJ
#   adult/NN
#   to/TO
#   reconcile/VB
#   social/JJ
#   perceptions/NNS
#   of/IN
#   his/PRP$
#   multiracial/JJ
#   heritage.In/NN
#   1963/CD
#   ,/,
#   (PERSON Dunham/NNP)
#   met/VBD
#   (PERSON Lolo/NNP Soetoro/NNP)
#   at/IN
#   the/DT
#   (ORGANIZATION University/NNP)
#   of/IN
#   (GPE Hawaii/NNP)
#   ;/:
#   he/PRP
#   was/VBD
#   an/DT
#   (GPE Indonesian/JJ)
#   East–West/NNP
#   Center/NNP
#   graduate/NN
#   student/NN
#   in/IN
#   geography/NN
#   ./.
#   The/DT
#   couple/NN
#   married/VBD
#   on/IN
#   (GPE Molokai/NNP)
#   on/IN
#   March/NNP
#   15/CD
#   ,/,
#   1965/CD
#   ./.
#   After/IN
#   two/CD
#   one-year/JJ
#   extensions/NNS
#   of/IN
#   his/PRP$
#   J-1/NNP
#   visa/NN
#   ,/,
#   (PERSON Lolo/NNP)
#   returned/VBD
#   to/TO
#   (GPE Indonesia/NNP)
#   in/IN
#   1966/CD
#   ./.
#   His/PRP$
#   wife/NN
#   and/CC
#   stepson/NN
#   followed/VBD
#   sixteen/JJ
#   months/NNS
#   later/RB
#   in/IN
#   1967/CD
#   ./.
#   The/DT
#   family/NN
#   initially/RB
#   lived/VBD
#   in/IN
#   the/DT
#   (ORGANIZATION Menteng/NNP Dalam/NNP)
#   neighborhood/NN
#   in/IN
#   the/DT
#   (ORGANIZATION Tebet/NNP)
#   district/NN
#   of/IN
#   (GPE South/NNP Jakarta/NNP)
#   ./.
#   From/IN
#   1970/CD
#   ,/,
#   they/PRP
#   lived/VBD
#   in/IN
#   a/DT
#   wealthier/JJR
#   neighborhood/NN
#   in/IN
#   the/DT
#   (ORGANIZATION Menteng/NNP)
#   district/NN
#   of/IN
#   (ORGANIZATION Central/NNP Jakarta/NNP)
#   ./.
#   Education/NN
#   At/IN
#   the/DT
#   age/NN
#   of/IN
#   six/CD
#   ,/,
#   (PERSON Obama/NNP)
#   and/CC
#   his/PRP$
#   mother/NN
#   had/VBD
#   moved/VBN
#   to/TO
#   (GPE Indonesia/NNP)
#   to/TO
#   join/VB
#   his/PRP$
#   stepfather/NN
#   ./.
#   From/IN
#   age/NN
#   six/CD
#   to/TO
#   ten/VB
#   ,/,
#   he/PRP
#   attended/VBD
#   local/JJ
#   Indonesian-language/JJ
#   schools/NNS
#   :/:
#   (PERSON
#     Sekolah/NNP
#     Dasar/NNP
#     Katolik/NNP
#     Santo/NNP
#     Fransiskus/NNP
#     Asisi/NNP)
#   (/(
#   (ORGANIZATION St./NNP Francis/NNP)
#   of/IN
#   (ORGANIZATION Assisi/NNP Catholic/NNP)
#   Elementary/NNP
#   School/NNP
#   )/)
#   for/IN
#   two/CD
#   years/NNS
#   and/CC
#   (PERSON Sekolah/NNP Dasar/NNP Negeri/NNP Menteng/NNP)
#   01/CD
#   (/(
#   (ORGANIZATION State/NNP Elementary/NNP School/NNP)
#   Menteng/NNP
#   01/CD
#   )/)
#   for/IN
#   one/CD
#   and/CC
#   a/DT
#   half/JJ
#   years/NNS
#   ,/,
#   supplemented/VBN
#   by/IN
#   English-language/NNP
#   (PERSON Calvert/NNP School/NNP)
#   homeschooling/NN
#   by/IN
#   his/PRP$
#   mother/NN
#   ./.
#   As/IN
#   a/DT
#   result/NN
#   of/IN
#   his/PRP$
#   four/CD
#   years/NNS
#   in/IN
#   (GPE Jakarta/NNP)
#   ,/,
#   he/PRP
#   was/VBD
#   able/JJ
#   to/TO
#   speak/VB
#   (GPE Indonesian/JJ)
#   fluently/RB
#   as/IN
#   a/DT
#   child/NN
#   ./.
#   During/IN
#   his/PRP$
#   time/NN
#   in/IN
#   (GPE Indonesia/NNP)
#   ,/,
#   (PERSON Obama/NNP)
#   's/POS
#   stepfather/NN
#   taught/VBD
#   him/PRP
#   to/TO
#   be/VB
#   resilient/JJ
#   and/CC
#   gave/VBD
#   him/PRP
#   ``/``
#   a/DT
#   pretty/RB
#   hardheaded/JJ
#   assessment/NN
#   of/IN
#   how/WRB
#   the/DT
#   world/NN
#   works/VBZ
#   ./.
#   ``/``
#   In/IN
#   1971/CD
#   ,/,
#   (PERSON Obama/NNP)
#   returned/VBD
#   to/TO
#   (GPE Honolulu/NNP)
#   to/TO
#   live/VB
#   with/IN
#   his/PRP$
#   maternal/JJ
#   grandparents/NNS
#   ,/,
#   (GPE Madelyn/NNP)
#   and/CC
#   (PERSON Stanley/NNP Dunham/NNP)
#   ./.
#   He/PRP
#   attended/VBD
#   (PERSON Punahou/NNP)
#   School—a/NNP
#   private/JJ
#   college/NN
#   preparatory/NN
#   school—with/VBD
#   the/DT
#   aid/NN
#   of/IN
#   a/DT
#   scholarship/NN
#   from/IN
#   fifth/JJ
#   grade/NN
#   until/IN
#   he/PRP
#   graduated/VBD
#   from/IN
#   high/JJ
#   school/NN
#   in/IN
#   1979/CD
#   ./.
#   In/IN
#   his/PRP$
#   youth/NN
#   ,/,
#   (PERSON Obama/NNP)
#   went/VBD
#   by/IN
#   the/DT
#   nickname/NN
#   ``/``
#   (PERSON Barry/NNP)
#   ./.
#   ''/''
#   (PERSON Obama/NNP)
#   lived/VBD
#   with/IN
#   his/PRP$
#   mother/NN
#   and/CC
#   half-sister/NN
#   ,/,
#   (PERSON Maya/NNP Soetoro/NNP)
#   ,/,
#   in/IN
#   (GPE Hawaii/NNP)
#   for/IN
#   three/CD
#   years/NNS
#   from/IN
#   1972/CD
#   to/TO
#   1975/CD
#   while/IN
#   his/PRP$
#   mother/NN
#   was/VBD
#   a/DT
#   graduate/JJ
#   student/NN
#   in/IN
#   anthropology/NN
#   at/IN
#   the/DT
#   (ORGANIZATION University/NNP)
#   of/IN
#   (GPE Hawaii/NNP)
#   ./.
#   (PERSON Obama/NNP)
#   chose/VBD
#   to/TO
#   stay/VB
#   in/IN
#   (GPE Hawaii/NNP)
#   when/WRB
#   his/PRP$
#   mother/NN
#   and/CC
#   half-sister/NN
#   returned/VBN
#   to/TO
#   (GPE Indonesia/NNP)
#   in/IN
#   1975/CD
#   ,/,
#   so/IN
#   his/PRP$
#   mother/NN
#   could/MD
#   begin/VB
#   anthropology/JJ
#   field/NN
#   work/NN
#   ./.
#   His/PRP$
#   mother/NN
#   spent/VBD
#   most/JJS
#   of/IN
#   the/DT
#   next/JJ
#   two/CD
#   decades/NNS
#   in/IN
#   (GPE Indonesia/NNP)
#   ,/,
#   divorcing/VBG
#   (PERSON Lolo/NNP)
#   in/IN
#   1980/CD
#   and/CC
#   earning/VBG
#   a/DT
#   (ORGANIZATION PhD/NNP)
#   degree/NN
#   in/IN
#   1992/CD
#   ,/,
#   before/IN
#   dying/VBG
#   in/IN
#   1995/CD
#   in/IN
#   (GPE Hawaii/NNP)
#   following/VBG
#   unsuccessful/JJ
#   treatment/NN
#   for/IN
#   ovarian/JJ
#   and/CC
#   uterine/JJ
#   cancer.Of/NN
#   his/PRP$
#   years/NNS
#   in/IN
#   (GPE Honolulu/NNP)
#   ,/,
#   (PERSON Obama/NNP)
#   wrote/VBD
#   :/:
#   ``/``
#   The/DT
#   opportunity/NN
#   that/WDT
#   (PERSON Hawaii/NNP)
#   offered/VBD
#   —/NNP
#   to/TO
#   experience/VB
#   a/DT
#   variety/NN
#   of/IN
#   cultures/NNS
#   in/IN
#   a/DT
#   climate/NN
#   of/IN
#   mutual/JJ
#   respect/NN
#   —/NNP
#   became/VBD
#   an/DT
#   integral/JJ
#   part/NN
#   of/IN
#   my/PRP$
#   world/NN
#   view/NN
#   ,/,
#   and/CC
#   a/DT
#   basis/NN
#   for/IN
#   the/DT
#   values/NNS
#   that/IN
#   I/PRP
#   hold/VBP
#   most/RBS
#   dear/JJ
#   ./.
#   ''/''
#   (PERSON Obama/NNP)
#   has/VBZ
#   also/RB
#   written/VBN
#   and/CC
#   talked/VBN
#   about/IN
#   using/VBG
#   alcohol/NN
#   ,/,
#   marijuana/NN
#   ,/,
#   and/CC
#   cocaine/NN
#   during/IN
#   his/PRP$
#   teenage/NN
#   years/NNS
#   to/TO
#   ``/``
#   push/JJ
#   questions/NNS
#   of/IN
#   who/WP
#   I/PRP
#   was/VBD
#   out/IN
#   of/IN
#   my/PRP$
#   mind/NN
#   ./.
#   ''/''
#   (PERSON Obama/NNP)
#   was/VBD
#   also/RB
#   a/DT
#   member/NN
#   of/IN
#   the/DT
#   ``/``
#   choom/NN
#   gang/NN
#   ''/''
#   ,/,
#   a/DT
#   self-named/JJ
#   group/NN
#   of/IN
#   friends/NNS
#   who/WP
#   spent/VBD
#   time/NN
#   together/RB
#   and/CC
#   occasionally/RB
#   smoked/VBD
#   marijuana/NNS
#   ./.
#   (PERSON College/NNP)
#   and/CC
#   research/NN
#   jobs/NNS
#   After/IN
#   graduating/VBG
#   from/IN
#   high/JJ
#   school/NN
#   in/IN
#   1979/CD
#   ,/,
#   (PERSON Obama/NNP)
#   moved/VBD
#   to/TO
#   (GPE Los/NNP Angeles/NNP)
#   to/TO
#   attend/VB
#   (ORGANIZATION Occidental/NNP College/NNP)
#   on/IN
#   a/DT
#   full/JJ
#   scholarship/NN
#   ./.
#   In/IN
#   February/NNP
#   1981/CD
#   ,/,
#   (PERSON Obama/NNP)
#   made/VBD
#   his/PRP$
#   first/JJ
#   public/JJ
#   speech/NN
#   ,/,
#   calling/VBG
#   for/IN
#   (ORGANIZATION Occidental/NNP)
#   to/TO
#   participate/VB
#   in/IN
#   the/DT
#   disinvestment/NN
#   from/IN
#   (GPE South/NNP Africa/NNP)
#   in/IN
#   response/NN
#   to/TO
#   that/DT
#   nation/NN
#   's/POS
#   policy/NN
#   of/IN
#   apartheid/NN
#   ./.
#   In/IN
#   mid-1981/NN
#   ,/,
#   (PERSON Obama/NNP)
#   traveled/VBD
#   to/TO
#   (GPE Indonesia/NNP)
#   to/TO
#   visit/VB
#   his/PRP$
#   mother/NN
#   and/CC
#   half-sister/NN
#   Maya/NNP
#   ,/,
#   and/CC
#   visited/VBD
#   the/DT
#   families/NNS
#   of/IN
#   college/NN
#   friends/NNS
#   in/IN
#   (GPE Pakistan/NNP)
#   for/IN
#   three/CD
#   weeks/NNS
#   ./.
#   Later/RB
#   in/IN
#   1981/CD
#   ,/,
#   he/PRP
#   transferred/VBD
#   to/TO
#   (ORGANIZATION Columbia/NNP University/NNP)
#   in/IN
#   (GPE New/NNP York/NNP City/NNP)
#   as/IN
#   a/DT
#   junior/NN
#   ,/,
#   where/WRB
#   he/PRP
#   majored/VBD
#   in/IN
#   political/JJ
#   science/NN
#   with/IN
#   a/DT
#   specialty/NN
#   in/IN
#   international/JJ
#   relations/NNS
#   and/CC
#   in/IN
#   (GPE English/NNP)
#   literature/NN
#   and/CC
#   lived/VBD
#   off-campus/NN
#   on/IN
#   West/NNP
#   109th/CD
#   Street/NNP
#   ./.
#   He/PRP
#   graduated/VBD
#   with/IN
#   a/DT
#   Bachelor/NNP
#   of/IN
#   (GPE Arts/NNP)
#   degree/NN
#   in/IN
#   1983/CD
#   and/CC
#   a/DT
#   3.7/CD
#   GPA/NNP
#   ./.
#   After/IN
#   graduating/VBG
#   ,/,
#   (PERSON Obama/NNP)
#   worked/VBD
#   for/IN
#   about/IN
#   a/DT
#   year/NN
#   at/IN
#   the/DT
#   (ORGANIZATION Business/NNP International/NNP Corporation/NNP)
#   ,/,
#   where/WRB
#   he/PRP
#   was/VBD
#   a/DT
#   financial/JJ
#   researcher/NN
#   and/CC
#   writer/NN
#   ,/,
#   then/RB
#   as/IN
#   a/DT
#   project/NN
#   coordinator/NN
#   for/IN
#   the/DT
#   (GPE New/NNP York/NNP)
#   Public/NNP
#   Interest/NNP
#   Research/NNP
#   Group/NNP
#   on/IN
#   the/DT
#   (ORGANIZATION City/NNP College/NNP)
#   of/IN
#   (GPE New/NNP York/NNP)
#   campus/NN
#   for/IN
#   three/CD
#   months/NNS
#   in/IN
#   1985/CD
#   ./.
#   (ORGANIZATION Community/NNP)
#   organizer/NN
#   and/CC
#   (ORGANIZATION Harvard/NNP Law/NNP)
#   School/NNP
#   Two/CD
#   years/NNS
#   after/IN
#   graduating/VBG
#   from/IN
#   (GPE Columbia/NNP)
#   ,/,
#   (PERSON Obama/NNP)
#   moved/VBD
#   from/IN
#   (GPE New/NNP York/NNP)
#   to/TO
#   (GPE Chicago/NNP)
#   when/WRB
#   he/PRP
#   was/VBD
#   hired/VBN
#   as/IN
#   director/NN
#   of/IN
#   the/DT
#   (ORGANIZATION Developing/NNP)
#   Communities/NNP
#   Project/NNP
#   ,/,
#   a/DT
#   church-based/JJ
#   community/NN
#   organization/NN
#   originally/RB
#   comprising/VBG
#   eight/CD
#   (ORGANIZATION Catholic/NNP)
#   parishes/NNS
#   in/IN
#   (GPE Roseland/NNP)
#   ,/,
#   (GPE West/NNP Pullman/NNP)
#   ,/,
#   and/CC
#   (PERSON Riverdale/NNP)
#   on/IN
#   (GPE Chicago/NNP)
#   's/POS
#   (ORGANIZATION South/NNP Side/NNPS)
#   ./.
#   He/PRP
#   worked/VBD
#   there/RB
#   as/IN
#   a/DT
#   community/NN
#   organizer/NN
#   from/IN
#   June/NNP
#   1985/CD
#   to/TO
#   May/NNP
#   1988/CD
#   ./.
#   He/PRP
#   helped/VBD
#   set/VB
#   up/RP
#   a/DT
#   job/NN
#   training/NN
#   program/NN
#   ,/,
#   a/DT
#   college/NN
#   preparatory/NN
#   tutoring/VBG
#   program/NN
#   ,/,
#   and/CC
#   a/DT
#   tenants/NNS
#   '/POS
#   rights/NNS
#   organization/NN
#   in/IN
#   (GPE Altgeld/NNP Gardens/NNP)
#   ./.
#   (PERSON Obama/NNP)
#   also/RB
#   worked/VBD
#   as/IN
#   a/DT
#   consultant/NN
#   and/CC
#   instructor/NN
#   for/IN
#   the/DT
#   (ORGANIZATION Gamaliel/NNP Foundation/NNP)
#   ,/,
#   a/DT
#   community/NN
#   organizing/VBG
#   institute/NN
#   ./.
#   In/IN
#   (GPE mid-1988/JJ)
#   ,/,
#   he/PRP
#   traveled/VBD
#   for/IN
#   the/DT
#   first/JJ
#   time/NN
#   in/IN
#   (GPE Europe/NNP)
#   for/IN
#   three/CD
#   weeks/NNS
#   and/CC
#   then/RB
#   for/IN
#   five/CD
#   weeks/NNS
#   in/IN
#   (GPE Kenya/NNP)
#   ,/,
#   where/WRB
#   he/PRP
#   met/VBD
#   many/JJ
#   of/IN
#   his/PRP$
#   paternal/JJ
#   relatives/NNS
#   for/IN
#   the/DT
#   first/JJ
#   time/NN
#   ./.
#   Despite/IN
#   being/VBG
#   offered/VBN
#   a/DT
#   full/JJ
#   scholarship/NN
#   to/TO
#   (LOCATION Northwestern/NNP University/NNP School/NNP)
#   of/IN
#   (GPE Law/NNP)
#   ,/,
#   (PERSON Obama/NNP)
#   enrolled/VBD
#   at/IN
#   (ORGANIZATION Harvard/NNP Law/NNP School/NNP)
#   in/IN
#   the/DT
#   fall/NN
#   of/IN
#   1988/CD
#   ,/,
#   living/VBG
#   in/IN
#   nearby/JJ
#   Somerville/NNP
#   ,/,
#   (GPE Massachusetts/NNP)
#   ./.
#   He/PRP
#   was/VBD
#   selected/VBN
#   as/IN
#   an/DT
#   editor/NN
#   of/IN
#   the/DT
#   (ORGANIZATION Harvard/NNP Law/NNP Review/NNP)
#   at/IN
#   the/DT
#   end/NN
#   of/IN
#   his/PRP$
#   first/JJ
#   year/NN
#   ,/,
#   president/NN
#   of/IN
#   the/DT
#   journal/NN
#   in/IN
#   his/PRP$
#   second/JJ
#   year/NN
#   ,/,
#   and/CC
#   research/NN
#   assistant/NN
#   to/TO
#   the/DT
#   constitutional/JJ
#   scholar/NN
#   (PERSON Laurence/NNP Tribe/NNP)
#   while/IN
#   at/IN
#   (ORGANIZATION Harvard/NNP)
#   ./.
#   During/IN
#   his/PRP$
#   summers/NNS
#   ,/,
#   he/PRP
#   returned/VBD
#   to/TO
#   (GPE Chicago/NNP)
#   ,/,
#   where/WRB
#   he/PRP
#   worked/VBD
#   as/IN
#   a/DT
#   summer/NN
#   associate/NN
#   at/IN
#   the/DT
#   law/NN
#   firms/NNS
#   of/IN
#   (PERSON Sidley/NNP Austin/NNP)
#   in/IN
#   1989/CD
#   and/CC
#   (ORGANIZATION Hopkins/NNP)
#   &/CC
#   Sutter/NNP
#   in/IN
#   1990/CD
#   ./.
#   (PERSON Obama/NNP)
#   's/POS
#   election/NN
#   as/IN
#   the/DT
#   first/JJ
#   black/JJ
#   president/NN
#   of/IN
#   the/DT
#   (ORGANIZATION Harvard/NNP Law/NNP Review/NNP)
#   gained/VBD
#   national/JJ
#   media/NNS
#   attention/NN
#   and/CC
#   led/VBD
#   to/TO
#   a/DT
#   publishing/NN
#   contract/NN
#   and/CC
#   advance/NN
#   for/IN
#   a/DT
#   book/NN
#   about/IN
#   race/NN
#   relations/NNS
#   ,/,
#   which/WDT
#   evolved/VBD
#   into/IN
#   a/DT
#   personal/JJ
#   memoir/NN
#   ./.
#   The/DT
#   manuscript/NN
#   was/VBD
#   published/VBN
#   in/IN
#   mid-1995/NN
#   as/IN
#   (PERSON Dreams/NNP)
#   from/IN
#   My/PRP$
#   Father/NNP
#   ./.
#   (PERSON Obama/NNP)
#   graduated/VBD
#   from/IN
#   (ORGANIZATION Harvard/NNP Law/NNP)
#   in/IN
#   1991/CD
#   with/IN
#   a/DT
#   Juris/NNP
#   Doctor/NNP
#   magna/NN
#   cum/NN
#   laude/NN
#   ./.
#   (ORGANIZATION University/NNP)
#   of/IN
#   (GPE Chicago/NNP)
#   Law/NNP
#   School/NNP
#   In/IN
#   1991/CD
#   ,/,
#   (PERSON Obama/NNP)
#   accepted/VBD
#   a/DT
#   two-year/JJ
#   position/NN
#   as/IN
#   (ORGANIZATION Visiting/NNP Law/NNP)
#   and/CC
#   Government/NNP
#   Fellow/NNP
#   at/IN
#   the/DT
#   (ORGANIZATION University/NNP)
#   of/IN
#   (GPE Chicago/NNP)
#   Law/NNP
#   School/NNP
#   to/TO
#   work/VB
#   on/IN
#   his/PRP$
#   first/JJ
#   book/NN
#   ./.
#   He/PRP
#   then/RB
#   taught/VBD
#   constitutional/JJ
#   law/NN
#   at/IN
#   the/DT
#   (ORGANIZATION University/NNP)
#   of/IN
#   (GPE Chicago/NNP)
#   Law/NNP
#   School/NNP
#   for/IN
#   twelve/NN
#   years/NNS
#   ,/,
#   first/RB
#   as/IN
#   a/DT
#   lecturer/NN
#   from/IN
#   1992/CD
#   to/TO
#   1996/CD
#   ,/,
#   and/CC
#   then/RB
#   as/IN
#   a/DT
#   senior/JJ
#   lecturer/NN
#   from/IN
#   1996/CD
#   to/TO
#   2004.From/CD
#   April/NNP
#   to/TO
#   October/NNP
#   1992/CD
#   ,/,
#   (PERSON Obama/NNP)
#   directed/VBD
#   (PERSON Illinois/NNP)
#   's/POS
#   Project/NNP
#   Vote/NNP
#   ,/,
#   a/DT
#   voter/NN
#   registration/NN
#   campaign/NN
#   with/IN
#   ten/JJ
#   staffers/NNS
#   and/CC
#   seven/CD
#   hundred/VBD
#   volunteer/NN
#   registrars/NNS
#   ;/:
#   it/PRP
#   achieved/VBD
#   its/PRP$
#   goal/NN
#   of/IN
#   registering/VBG
#   150,000/CD
#   of/IN
#   400,000/CD
#   unregistered/JJ
#   (ORGANIZATION African/JJ Americans/NNPS)
#   in/IN
#   the/DT
#   state/NN
#   ,/,
#   leading/VBG
#   (PERSON Crain/NNP)
#   's/POS
#   (ORGANIZATION Chicago/NNP Business/NNP)
#   to/TO
#   name/VB
#   (PERSON Obama/NNP)
#   to/TO
#   its/PRP$
#   1993/CD
#   list/NN
#   of/IN
#   ``/``
#   40/CD
#   under/IN
#   Forty/NNP
#   ''/''
#   powers/NNS
#   to/TO
#   be/VB
#   ./.
#   (PERSON Family/NNP)
#   and/CC
#   personal/JJ
#   life/NN
#   In/IN
#   a/DT
#   2006/CD
#   interview/NN
#   ,/,
#   (PERSON Obama/NNP)
#   highlighted/VBD
#   the/DT
#   diversity/NN
#   of/IN
#   his/PRP$
#   extended/JJ
#   family/NN
#   :/:
#   ``/``
#   It/PRP
#   's/VBZ
#   like/IN
#   a/DT
#   little/JJ
#   mini-United/JJ
#   Nations/NNS
#   ,/,
#   ''/''
#   he/PRP
#   said/VBD
#   ./.
#   ``/``
#   I/PRP
#   've/VBP
#   got/VBN
#   relatives/NNS
#   who/WP
#   look/VBP
#   like/IN
#   (PERSON Bernie/NNP Mac/NNP)
#   ,/,
#   and/CC
#   I/PRP
#   've/VBP
#   got/VBN
#   relatives/NNS
#   who/WP
#   look/VBP
#   like/IN
#   (PERSON Margaret/NNP Thatcher/NNP)
#   ./.
#   ''/''
#   (PERSON Obama/NNP)
#   has/VBZ
#   a/DT
#   half-sister/NN
#   with/IN
#   whom/WP
#   he/PRP
#   was/VBD
#   raised/VBN
#   (/(
#   (ORGANIZATION Maya/NNP)
#   Soetoro-Ng/NNP
#   )/)
#   and/CC
#   seven/CD
#   other/JJ
#   half-siblings/NNS
#   from/IN
#   his/PRP$
#   (GPE Kenyan/NNP)
#   father/NN
#   's/POS
#   family—six/NN
#   of/IN
#   them/PRP
#   living/VBG
#   ./.
#   (PERSON Obama/NNP)
#   's/POS
#   mother/NN
#   was/VBD
#   survived/VBN
#   by/IN
#   her/PRP$
#   Kansas-born/NNP
#   mother/NN
#   ,/,
#   (PERSON Madelyn/NNP Dunham/NNP)
#   ,/,
#   until/IN
#   her/PRP$
#   death/NN
#   on/IN
#   November/NNP
#   2/CD
#   ,/,
#   2008/CD
#   ,/,
#   two/CD
#   days/NNS
#   before/IN
#   his/PRP$
#   election/NN
#   to/TO
#   the/DT
#   presidency/NN
#   ./.
#   (PERSON Obama/NNP)
#   also/RB
#   has/VBZ
#   roots/NNS
#   in/IN
#   (GPE Ireland/NNP)
#   ;/:
#   he/PRP
#   met/VBD
#   with/IN
#   his/PRP$
#   (GPE Irish/JJ)
#   cousins/NNS
#   in/IN
#   (GPE Moneygall/NNP)
#   in/IN
#   May/NNP
#   2011/CD
#   ./.
#   In/IN
#   (GPE Dreams/NNP)
#   from/IN
#   My/NNP
#   Father/NNP
#   ,/,
#   (PERSON Obama/NNP)
#   ties/VBZ
#   his/PRP$
#   mother/NN
#   's/POS
#   family/NN
#   history/NN
#   to/TO
#   possible/JJ
#   Native/JJ
#   (GPE American/JJ)
#   ancestors/NNS
#   and/CC
#   distant/JJ
#   relatives/NNS
#   of/IN
#   (PERSON Jefferson/NNP Davis/NNP)
#   ,/,
#   President/NNP
#   of/IN
#   the/DT
#   (ORGANIZATION Confederate/NNP States/NNPS)
#   of/IN
#   (GPE America/NNP)
#   during/IN
#   the/DT
#   (ORGANIZATION American/NNP)
#   Civil/NNP
#   War/NNP
#   ./.
#   He/PRP
#   also/RB
#   shares/NNS
#   distant/JJ
#   ancestors/NNS
#   in/IN
#   common/JJ
#   with/IN
#   (PERSON George/NNP W./NNP Bush/NNP)
#   and/CC
#   (PERSON Dick/NNP Cheney/NNP)
#   ,/,
#   among/IN
#   others.Obama/JJ
#   lived/VBD
#   with/IN
#   anthropologist/JJ
#   (ORGANIZATION Sheila/NNP Miyoshi/NNP Jager/NNP)
#   while/IN
#   he/PRP
#   was/VBD
#   a/DT
#   community/NN
#   organizer/NN
#   in/IN
#   (GPE Chicago/NNP)
#   in/IN
#   the/DT
#   1980s/NNS
#   ./.
#   He/PRP
#   proposed/VBD
#   to/TO
#   her/PRP$
#   twice/NN
#   ,/,
#   but/CC
#   both/DT
#   Jager/NNP
#   and/CC
#   her/PRP$
#   parents/NNS
#   turned/VBD
#   him/PRP
#   down/RP
#   ./.
#   The/DT
#   relationship/NN
#   was/VBD
#   not/RB
#   made/VBN
#   public/JJ
#   until/IN
#   May/NNP
#   2017/CD
#   ,/,
#   several/JJ
#   months/NNS
#   after/IN
#   his/PRP$
#   presidency/NN
#   had/VBD
#   ended/VBN
#   ./.
#   In/IN
#   June/NNP
#   1989/CD
#   ,/,
#   (PERSON Obama/NNP)
#   met/VBD
#   (PERSON Michelle/NNP Robinson/NNP)
#   when/WRB
#   he/PRP
#   was/VBD
#   employed/VBN
#   as/IN
#   a/DT
#   summer/NN
#   associate/NN
#   at/IN
#   the/DT
#   (GPE Chicago/NNP)
#   law/NN
#   firm/NN
#   of/IN
#   (PERSON Sidley/NNP Austin/NNP)
#   ./.
#   (PERSON Robinson/NNP)
#   was/VBD
#   assigned/VBN
#   for/IN
#   three/CD
#   months/NNS
#   as/IN
#   (PERSON Obama/NNP)
#   's/POS
#   adviser/NN
#   at/IN
#   the/DT
#   firm/NN
#   ,/,
#   and/CC
#   she/PRP
#   joined/VBD
#   him/PRP
#   at/IN
#   several/JJ
#   group/NN
#   social/JJ
#   functions/NNS
#   but/CC
#   declined/VBD
#   his/PRP$
#   initial/JJ
#   requests/NNS
#   to/TO
#   date/NN
#   ./.
#   They/PRP
#   began/VBD
#   dating/VBG
#   later/RB
#   that/IN
#   summer/NN
#   ,/,
#   became/VBD
#   engaged/VBN
#   in/IN
#   1991/CD
#   ,/,
#   and/CC
#   were/VBD
#   married/VBN
#   on/IN
#   October/NNP
#   3/CD
#   ,/,
#   1992/CD
#   ./.
#   After/IN
#   suffering/VBG
#   a/DT
#   miscarriage/NN
#   ,/,
#   (GPE Michelle/NNP)
#   underwent/NN
#   in/IN
#   vitro/JJ
#   fertilization/NN
#   to/TO
#   conceive/VB
#   their/PRP$
#   children/NNS
#   ./.
#   The/DT
#   couple/NN
#   's/POS
#   first/JJ
#   daughter/NN
#   ,/,
#   (PERSON Malia/NNP Ann/NNP)
#   ,/,
#   was/VBD
#   born/VBN
#   in/IN
#   1998/CD
#   ,/,
#   followed/VBN
#   by/IN
#   a/DT
#   second/JJ
#   daughter/NN
#   ,/,
#   (GPE Natasha/NNP)
#   (/(
#   ``/``
#   Sasha/NNP
#   ''/''
#   )/)
#   ,/,
#   in/IN
#   2001/CD
#   ./.
#   The/DT
#   (ORGANIZATION Obama/NNP)
#   daughters/NNS
#   attended/VBD
#   the/DT
#   (ORGANIZATION University/NNP)
#   of/IN
#   (GPE Chicago/NNP)
#   Laboratory/NNP
#   Schools/NNP
#   ./.
#   When/WRB
#   they/PRP
#   moved/VBD
#   to/TO
#   (GPE Washington/NNP)
#   ,/,
#   (GPE D.C./NNP)
#   ,/,
#   in/IN
#   January/NNP
#   2009/CD
#   ,/,
#   the/DT
#   girls/NNS
#   started/VBD
#   at/IN
#   the/DT
#   (ORGANIZATION Sidwell/NNP Friends/NNP School/NNP)
#   ./.
#   The/DT
#   (ORGANIZATION Obamas/NNPS)
#   had/VBD
#   two/CD
#   (GPE Portuguese/JJ)
#   Water/NNP
#   Dogs/NNP
#   ;/:
#   the/DT
#   first/JJ
#   ,/,
#   a/DT
#   male/NN
#   named/VBN
#   Bo/NNP
#   ,/,
#   was/VBD
#   a/DT
#   gift/NN
#   from/IN
#   (ORGANIZATION Senator/NNP Ted/NNP Kennedy/NNP)
#   ./.
#   In/IN
#   2013/CD
#   ,/,
#   (PERSON Bo/NNP)
#   was/VBD
#   joined/VBN
#   by/IN
#   (PERSON Sunny/NNP)
#   ,/,
#   a/DT
#   female/NN
#   ./.
#   (PERSON Bo/NNP)
#   died/VBD
#   of/IN
#   cancer/NN
#   on/IN
#   May/NNP
#   8/CD
#   ,/,
#   2021/CD
#   ./.
#   (PERSON Obama/NNP)
#   is/VBZ
#   a/DT
#   supporter/NN
#   of/IN
#   the/DT
#   (ORGANIZATION Chicago/NNP)
#   (FACILITY White/NNP Sox/NNP)
#   ,/,
#   and/CC
#   he/PRP
#   threw/VBD
#   out/RP
#   the/DT
#   first/JJ
#   pitch/NN
#   at/IN
#   the/DT
#   2005/CD
#   ALCS/NNP
#   when/WRB
#   he/PRP
#   was/VBD
#   still/RB
#   a/DT
#   senator/NN
#   ./.
#   In/IN
#   2009/CD
#   ,/,
#   he/PRP
#   threw/VBD
#   out/RP
#   the/DT
#   ceremonial/NN
#   first/RB
#   pitch/NN
#   at/IN
#   the/DT
#   All-Star/NNP
#   Game/NNP
#   while/IN
#   wearing/VBG
#   a/DT
#   (ORGANIZATION White/NNP Sox/NNPS)
#   jacket/NN
#   ./.
#   He/PRP
#   is/VBZ
#   also/RB
#   primarily/RB
#   a/DT
#   (ORGANIZATION Chicago/NNP Bears/NNP)
#   football/NN
#   fan/NN
#   in/IN
#   the/DT
#   (ORGANIZATION NFL/NNP)
#   ,/,
#   but/CC
#   in/IN
#   his/PRP$
#   childhood/NN
#   and/CC
#   adolescence/NN
#   was/VBD
#   a/DT
#   fan/NN
#   of/IN
#   the/DT
#   (ORGANIZATION Pittsburgh/NNP Steelers/NNP)
#   ,/,
#   and/CC
#   rooted/VBN
#   for/IN
#   them/PRP
#   ahead/RB
#   of/IN
#   their/PRP$
#   victory/NN
#   in/IN
#   (GPE Super/NNP)
#   Bowl/NNP
#   XLIII/NNP
#   12/CD
#   days/NNS
#   after/IN
#   he/PRP
#   took/VBD
#   office/NN
#   as/IN
#   president/NN
#   ./.
#   In/IN
#   2011/CD
#   ,/,
#   (PERSON Obama/NNP)
#   invited/VBD
#   the/DT
#   1985/CD
#   (GPE Chicago/NNP)
#   Bears/NNP
#   to/TO
#   the/DT
#   (FACILITY White/NNP House/NNP)
#   ;/:
#   the/DT
#   team/NN
#   had/VBD
#   not/RB
#   visited/VBN
#   the/DT
#   (FACILITY White/NNP House/NNP)
#   after/IN
#   their/PRP$
#   Super/NNP
#   Bowl/NNP
#   win/NN
#   in/IN
#   1986/CD
#   due/JJ
#   to/TO
#   the/DT
#   (ORGANIZATION Space/NNP Shuttle/NNP)
#   Challenger/NNP
#   disaster/NN
#   ./.
#   He/PRP
#   plays/VBZ
#   basketball/NN
#   ,/,
#   a/DT
#   sport/NN
#   he/PRP
#   participated/VBD
#   in/IN
#   as/IN
#   a/DT
#   member/NN
#   of/IN
#   his/PRP$
#   high/JJ
#   school/NN
#   's/POS
#   varsity/NN
#   team/NN
#   ,/,
#   and/CC
#   he/PRP
#   is/VBZ
#   left-handed.In/JJ
#   2005/CD
#   ,/,
#   the/DT
#   (GPE Obama/NNP)
#   family/NN
#   applied/VBD
#   the/DT
#   proceeds/NNS
#   of/IN
#   a/DT
#   book/NN
#   deal/NN
#   and/CC
#   moved/VBN
#   from/IN
#   a/DT
#   (ORGANIZATION Hyde/NNP Park/NNP)
#   ,/,
#   (GPE Chicago/NNP)
#   condominium/NN
#   to/TO
#   a/DT
#   $/$
#   1.6/CD
#   million/CD
#   house/NN
#   (/(
#   equivalent/JJ
#   to/TO
#   $/$
#   2.2/CD
#   million/CD
#   in/IN
#   2021/CD
#   )/)
#   in/IN
#   neighboring/VBG
#   (PERSON Kenwood/NNP)
#   ,/,
#   (GPE Chicago/NNP)
#   ./.
#   The/DT
#   purchase/NN
#   of/IN
#   an/DT
#   adjacent/JJ
#   lot—and/NN
#   sale/NN
#   of/IN
#   part/NN
#   of/IN
#   it/PRP
#   to/TO
#   (GPE Obama/NNP)
#   by/IN
#   the/DT
#   wife/NN
#   of/IN
#   developer/NN
#   ,/,
#   campaign/NN
#   donor/NN
#   and/CC
#   friend/NN
#   (PERSON Tony/NNP)
#   Rezko—attracted/NNP
#   media/NNS
#   attention/NN
#   because/IN
#   of/IN
#   (GPE Rezko/NNP)
#   's/POS
#   subsequent/JJ
#   indictment/NN
#   and/CC
#   conviction/NN
#   on/IN
#   political/JJ
#   corruption/NN
#   charges/NNS
#   that/WDT
#   were/VBD
#   unrelated/JJ
#   to/TO
#   Obama.In/NNP
#   December/NNP
#   2007/CD
#   ,/,
#   (PERSON Money/NNP Magazine/NNP)
#   estimated/VBN
#   (PERSON Obama/NNP)
#   's/POS
#   net/JJ
#   worth/NN
#   at/IN
#   $/$
#   1.3/CD
#   million/CD
#   (/(
#   equivalent/JJ
#   to/TO
#   $/$
#   1.7/CD
#   million/CD
#   in/IN
#   2021/CD
#   )/)
#   ./.
#   Their/PRP$
#   2009/CD
#   tax/NN
#   return/NN
#   showed/VBD
#   a/DT
#   household/JJ
#   income/NN
#   of/IN
#   $/$
#   5.5/CD
#   million—up/NN
#   from/IN
#   about/IN
#   $/$
#   4.2/CD
#   million/CD
#   in/IN
#   2007/CD
#   and/CC
#   $/$
#   1.6/CD
#   million/CD
#   in/IN
#   2005—mostly/CD
#   from/IN
#   sales/NNS
#   of/IN
#   his/PRP$
#   books/NNS
#   ./.
#   On/IN
#   his/PRP$
#   2010/CD
#   income/NN
#   of/IN
#   $/$
#   1.7/CD
#   million/CD
#   ,/,
#   he/PRP
#   gave/VBD
#   14/CD
#   percent/NN
#   to/TO
#   non-profit/JJ
#   organizations/NNS
#   ,/,
#   including/VBG
#   $/$
#   131,000/CD
#   to/TO
#   (PERSON Fisher/NNP House/NNP Foundation/NNP)
#   ,/,
#   a/DT
#   charity/NN
#   assisting/VBG
#   wounded/VBD
#   veterans/NNS
#   '/POS
#   families/NNS
#   ,/,
#   allowing/VBG
#   them/PRP
#   to/TO
#   reside/VB
#   near/IN
#   where/WRB
#   the/DT
#   veteran/NN
#   is/VBZ
#   receiving/VBG
#   medical/JJ
#   treatments/NNS
#   ./.
#   Per/IN
#   his/PRP$
#   2012/CD
#   financial/JJ
#   disclosure/NN
#   ,/,
#   (PERSON Obama/NNP)
#   may/MD
#   be/VB
#   worth/JJ
#   as/RB
#   much/JJ
#   as/IN
#   $/$
#   10/CD
#   million/CD
#   ./.
#   Last/JJ
#   name/NN
#   (PERSON Obama/NNP)
#   's/POS
#   last/JJ
#   name/NN
#   originates/NNS
#   from/IN
#   (GPE Luo/NNP)
#   people/NNS
#   ./.
#   In/IN
#   (GPE Luo/NNP)
#   language/NN
#   ,/,
#   it/PRP
#   means/VBZ
#   ``/``
#   bent/NN
#   over/IN
#   ''/''
#   or/CC
#   ``/``
#   limping/JJ
#   ''/''
#   ./.
#   Religious/JJ
#   views/NNS
#   (PERSON Obama/NNP)
#   is/VBZ
#   a/DT
#   (ORGANIZATION Protestant/JJ Christian/NNP)
#   whose/WP$
#   religious/JJ
#   views/NNS
#   developed/VBN
#   in/IN
#   his/PRP$
#   adult/NN
#   life/NN
#   ./.
#   He/PRP
#   wrote/VBD
#   in/IN
#   The/DT
#   (ORGANIZATION Audacity/NNP)
#   of/IN
#   (GPE Hope/NNP)
#   that/IN
#   he/PRP
#   ``/``
#   was/VBD
#   not/RB
#   raised/VBN
#   in/IN
#   a/DT
#   religious/JJ
#   household/NN
#   ./.
#   ''/''
#   He/PRP
#   described/VBD
#   his/PRP$
#   mother/NN
#   ,/,
#   raised/VBN
#   by/IN
#   non-religious/JJ
#   parents/NNS
#   ,/,
#   as/IN
#   being/VBG
#   detached/VBN
#   from/IN
#   religion/NN
#   ,/,
#   yet/RB
#   ``/``
#   in/IN
#   many/JJ
#   ways/NNS
#   the/DT
#   most/RBS
#   spiritually/RB
#   awakened/JJ
#   person/NN
#   .../:
#   I/PRP
#   have/VBP
#   ever/RB
#   known/VBN
#   ''/''
#   ,/,
#   and/CC
#   ``/``
#   a/DT
#   lonely/JJ
#   witness/NN
#   for/IN
#   secular/JJ
#   humanism/NN
#   ./.
#   ''/''
#   He/PRP
#   described/VBD
#   his/PRP$
#   father/NN
#   as/IN
#   a/DT
#   ``/``
#   confirmed/JJ
#   atheist/NN
#   ''/''
#   by/IN
#   the/DT
#   time/NN
#   his/PRP$
#   parents/NNS
#   met/VBD
#   ,/,
#   and/CC
#   his/PRP$
#   stepfather/NN
#   as/IN
#   ``/``
#   a/DT
#   man/NN
#   who/WP
#   saw/VBD
#   religion/NN
#   as/IN
#   not/RB
#   particularly/RB
#   useful/JJ
#   ./.
#   ''/''
#   (PERSON Obama/NNP)
#   explained/VBD
#   how/WRB
#   ,/,
#   through/IN
#   working/VBG
#   with/IN
#   black/JJ
#   churches/NNS
#   as/IN
#   a/DT
#   community/NN
#   organizer/NN
#   while/IN
#   in/IN
#   his/PRP$
#   twenties/NNS
#   ,/,
#   he/PRP
#   came/VBD
#   to/TO
#   understand/VB
#   ``/``
#   the/DT
#   power/NN
#   of/IN
#   the/DT
#   African-American/JJ
#   religious/JJ
#   tradition/NN
#   to/TO
#   spur/VB
#   social/JJ
#   change/NN
#   ./.
#   ''/''
#   In/IN
#   January/NNP
#   2008/CD
#   ,/,
#   (PERSON Obama/NNP)
#   told/VBD
#   (ORGANIZATION Christianity/NNP)
#   Today/NNP
#   :/:
#   ``/``
#   I/PRP
#   am/VBP
#   a/DT
#   (GPE Christian/JJ)
#   ,/,
#   and/CC
#   I/PRP
#   am/VBP
#   a/DT
#   devout/NN
#   (PERSON Christian/NNP)
#   ./.
#   I/PRP
#   believe/VBP
#   in/IN
#   the/DT
#   redemptive/JJ
#   death/NN
#   and/CC
#   resurrection/NN
#   of/IN
#   (PERSON Jesus/NNP Christ/NNP)
#   ./.
#   I/PRP
#   believe/VBP
#   that/IN
#   faith/NN
#   gives/VBZ
#   me/PRP
#   a/DT
#   path/NN
#   to/TO
#   be/VB
#   cleansed/VBN
#   of/IN
#   sin/NN
#   and/CC
#   have/VBP
#   eternal/JJ
#   life/NN
#   ./.
#   ''/''
#   On/IN
#   September/NNP
#   27/CD
#   ,/,
#   2010/CD
#   ,/,
#   (PERSON Obama/NNP)
#   released/VBD
#   a/DT
#   statement/NN
#   commenting/VBG
#   on/IN
#   his/PRP$
#   religious/JJ
#   views/NNS
#   ,/,
#   saying/VBG
#   :/:
#   I/PRP
#   'm/VBP
#   a/DT
#   (GPE Christian/JJ)
#   by/IN
#   choice/NN
#   ./.
#   My/PRP$
#   family/NN
#   didn't—frankly/RB
#   ,/,
#   they/PRP
#   were/VBD
#   n't/RB
#   folks/NNS
#   who/WP
#   went/VBD
#   to/TO
#   church/VB
#   every/DT
#   week/NN
#   ./.
#   And/CC
#   my/PRP$
#   mother/NN
#   was/VBD
#   one/CD
#   of/IN
#   the/DT
#   most/RBS
#   spiritual/JJ
#   people/NNS
#   I/PRP
#   knew/VBD
#   ,/,
#   but/CC
#   she/PRP
#   did/VBD
#   n't/RB
#   raise/VB
#   me/PRP
#   in/IN
#   the/DT
#   church/NN
#   ./.
#   So/IN
#   I/PRP
#   came/VBD
#   to/TO
#   my/PRP$
#   (GPE Christian/JJ)
#   faith/NN
#   later/RBR
#   in/IN
#   life/NN
#   ,/,
#   and/CC
#   it/PRP
#   was/VBD
#   because/IN
#   the/DT
#   precepts/NNS
#   of/IN
#   (PERSON Jesus/NNP Christ/NNP)
#   spoke/VBD
#   to/TO
#   me/PRP
#   in/IN
#   terms/NNS
#   of/IN
#   the/DT
#   kind/NN
#   of/IN
#   life/NN
#   that/IN
#   I/PRP
#   would/MD
#   want/VB
#   to/TO
#   lead—being/VBG
#   my/PRP$
#   brothers/NNS
#   '/POS
#   and/CC
#   sisters/NNS
#   '/POS
#   keeper/NN
#   ,/,
#   treating/VBG
#   others/NNS
#   as/IN
#   they/PRP
#   would/MD
#   treat/VB
#   me/PRP
#   ./.
#   (PERSON Obama/NNP)
#   met/VBD
#   (ORGANIZATION Trinity/NNP United/NNP Church/NNP)
#   of/IN
#   (GPE Christ/NNP)
#   pastor/NN
#   (PERSON Jeremiah/NNP Wright/NNP)
#   in/IN
#   October/NNP
#   1987/CD
#   and/CC
#   became/VBD
#   a/DT
#   member/NN
#   of/IN
#   (GPE Trinity/NNP)
#   in/IN
#   1992/CD
#   ./.
#   During/IN
#   (PERSON Obama/NNP)
#   's/POS
#   first/JJ
#   presidential/JJ
#   campaign/NN
#   in/IN
#   May/NNP
#   2008/CD
#   ,/,
#   he/PRP
#   resigned/VBD
#   from/IN
#   (GPE Trinity/NNP)
#   after/IN
#   some/DT
#   of/IN
#   (GPE Wright/NNP)
#   's/POS
#   statements/NNS
#   were/VBD
#   criticized/VBN
#   ./.
#   Since/IN
#   moving/VBG
#   to/TO
#   (GPE Washington/NNP)
#   ,/,
#   (GPE D.C./NNP)
#   ,/,
#   in/IN
#   2009/CD
#   ,/,
#   the/DT
#   (GPE Obama/NNP)
#   family/NN
#   has/VBZ
#   attended/VBN
#   several/JJ
#   (ORGANIZATION Protestant/NNP)
#   churches/NNS
#   ,/,
#   including/VBG
#   (PERSON Shiloh/NNP Baptist/NNP Church/NNP)
#   and/CC
#   (GPE St./NNP)
#   (PERSON John/NNP)
#   's/POS
#   (ORGANIZATION Episcopal/NNP Church/NNP)
#   ,/,
#   as/RB
#   well/RB
#   as/IN
#   (PERSON Evergreen/NNP Chapel/NNP)
#   at/IN
#   (FACILITY Camp/NNP David/NNP)
#   ,/,
#   but/CC
#   the/DT
#   members/NNS
#   of/IN
#   the/DT
#   family/NN
#   do/VBP
#   not/RB
#   attend/VB
#   church/NN
#   on/IN
#   a/DT
#   regular/JJ
#   basis.In/NN
#   2016/CD
#   ,/,
#   he/PRP
#   said/VBD
#   that/IN
#   he/PRP
#   gets/VBZ
#   inspiration/NN
#   from/IN
#   a/DT
#   few/JJ
#   items/NNS
#   that/WDT
#   remind/VBP
#   him/PRP
#   ``/``
#   of/IN
#   all/PDT
#   the/DT
#   different/JJ
#   people/NNS
#   I/PRP
#   've/VBP
#   met/VBN
#   along/IN
#   the/DT
#   way/NN
#   ''/''
#   ,/,
#   adding/VBG
#   :/:
#   ``/``
#   I/PRP
#   carry/VBP
#   these/DT
#   around/IN
#   all/PDT
#   the/DT
#   time/NN
#   ./.
#   I/PRP
#   'm/VBP
#   not/RB
#   that/IN
#   superstitious/JJ
#   ,/,
#   so/IN
#   it/PRP
#   's/VBZ
#   not/RB
#   like/IN
#   I/PRP
#   think/VBP
#   I/PRP
#   necessarily/RB
#   have/VBP
#   to/TO
#   have/VB
#   them/PRP
#   on/IN
#   me/PRP
#   at/IN
#   all/DT
#   times/NNS
#   ./.
#   ''/''
#   The/DT
#   items/NNS
#   ,/,
#   ``/``
#   a/DT
#   whole/JJ
#   bowl/NN
#   full/JJ
#   ''/''
#   ,/,
#   include/VBP
#   rosary/JJ
#   beads/NNS
#   given/VBN
#   to/TO
#   him/PRP
#   by/IN
#   (PERSON Pope/NNP Francis/NNP)
#   ,/,
#   a/DT
#   figurine/NN
#   of/IN
#   the/DT
#   (ORGANIZATION Hindu/NNP)
#   deity/NN
#   (PERSON Hanuman/NNP)
#   ,/,
#   a/DT
#   (ORGANIZATION Coptic/JJ)
#   cross/NN
#   from/IN
#   (GPE Ethiopia/NNP)
#   ,/,
#   a/DT
#   small/JJ
#   Buddha/NNP
#   statue/NN
#   given/VBN
#   by/IN
#   a/DT
#   monk/NN
#   ,/,
#   and/CC
#   a/DT
#   metal/NN
#   poker/NN
#   chip/NN
#   that/WDT
#   used/VBD
#   to/TO
#   be/VB
#   the/DT
#   lucky/JJ
#   charm/NN
#   of/IN
#   a/DT
#   motorcyclist/NN
#   in/IN
#   (GPE Iowa/NNP)
#   ./.
#   (PERSON Legal/NNP)
#   career/NN
#   (PERSON Civil/NNP Rights/NNP)
#   attorney/NN
#   He/PRP
#   joined/VBD
#   (PERSON Davis/NNP)
#   ,/,
#   (PERSON Miner/NNP)
#   ,/,
#   (PERSON Barnhill/NNP)
#   &/CC
#   (GPE Galland/NNP)
#   ,/,
#   a/DT
#   13-attorney/JJ
#   law/NN
#   firm/NN
#   specializing/VBG
#   in/IN
#   civil/JJ
#   rights/NNS
#   litigation/NN
#   and/CC
#   neighborhood/JJ
#   economic/JJ
#   development/NN
#   ,/,
#   where/WRB
#   he/PRP
#   was/VBD
#   an/DT
#   associate/NN
#   for/IN
#   three/CD
#   years/NNS
#   from/IN
#   1993/CD
#   to/TO
#   1996/CD
#   ,/,
#   then/RB
#   of/IN
#   counsel/NN
#   from/IN
#   1996/CD
#   to/TO
#   2004/CD
#   ./.
#   In/IN
#   1994/CD
#   ,/,
#   he/PRP
#   was/VBD
#   listed/VBN
#   as/IN
#   one/CD
#   of/IN
#   the/DT
#   lawyers/NNS
#   in/IN
#   Buycks-Roberson/NNP
#   v./NN
#   (ORGANIZATION Citibank/NNP Fed/NNP)
#   ./.
#   Sav/NNP
#   ./.
#   (PERSON Bank/NNP)
#   ,/,
#   94/CD
#   C/NNP
#   4094/CD
#   (/(
#   N.D./NNP
#   Ill./NNP
#   )/)
#   ./.
#   This/DT
#   class/NN
#   action/NN
#   lawsuit/NN
#   was/VBD
#   filed/VBN
#   in/IN
#   1994/CD
#   with/IN
#   (PERSON Selma/NNP Buycks-Roberson/NNP)
#   as/IN
#   lead/NN
#   plaintiff/NN
#   and/CC
#   alleged/VBD
#   that/IN
#   (ORGANIZATION Citibank/NNP Federal/NNP Savings/NNP Bank/NNP)
#   had/VBD
#   engaged/VBN
#   in/IN
#   practices/NNS
#   forbidden/VBN
#   under/IN
#   the/DT
#   (ORGANIZATION Equal/NNP Credit/NNP)
#   Opportunity/NNP
#   Act/NNP
#   and/CC
#   the/DT
#   (ORGANIZATION Fair/NNP Housing/NNP Act/NNP)
#   ./.
#   The/DT
#   case/NN
#   was/VBD
#   settled/VBN
#   out/IN
#   of/IN
#   court/NN
#   ./.
#   Final/JJ
#   judgment/NN
#   was/VBD
#   issued/VBN
#   on/IN
#   May/NNP
#   13/CD
#   ,/,
#   1998/CD
#   ,/,
#   with/IN
#   (ORGANIZATION Citibank/NNP Federal/NNP Savings/NNP Bank/NNP)
#   agreeing/VBG
#   to/TO
#   pay/VB
#   attorney/NN
#   fees.From/NN
#   1994/CD
#   to/TO
#   2002/CD
#   ,/,
#   (PERSON Obama/NNP)
#   served/VBD
#   on/IN
#   the/DT
#   boards/NNS
#   of/IN
#   directors/NNS
#   of/IN
#   the/DT
#   (ORGANIZATION Woods/NNP Fund/NNP)
#   of/IN
#   Chicago—which/NNP
#   in/IN
#   1985/CD
#   had/VBD
#   been/VBN
#   the/DT
#   first/JJ
#   foundation/NN
#   to/TO
#   fund/VB
#   the/DT
#   (ORGANIZATION Developing/NNP Communities/NNPS)
#   Project—and/NNP
#   of/IN
#   the/DT
#   (ORGANIZATION Joyce/NNP Foundation/NNP)
#   ./.
#   He/PRP
#   served/VBD
#   on/IN
#   the/DT
#   board/NN
#   of/IN
#   directors/NNS
#   of/IN
#   the/DT
#   (ORGANIZATION Chicago/NNP Annenberg/NNP)
#   Challenge/NNP
#   from/IN
#   1995/CD
#   to/TO
#   2002/CD
#   ,/,
#   as/IN
#   founding/JJ
#   president/NN
#   and/CC
#   chairman/NN
#   of/IN
#   the/DT
#   board/NN
#   of/IN
#   directors/NNS
#   from/IN
#   1995/CD
#   to/TO
#   1999/CD
#   ./.
#   (PERSON Obama/NNP)
#   's/POS
#   law/NN
#   license/NN
#   became/VBD
#   inactive/JJ
#   in/IN
#   2007/CD
#   ./.
#   Legislative/JJ
#   career/NN
#   (PERSON Illinois/NNP Senate/NNP)
#   (/(
#   1997–2004/CD
#   )/)
#   (PERSON Obama/NNP)
#   was/VBD
#   elected/VBN
#   to/TO
#   the/DT
#   (ORGANIZATION Illinois/NNP Senate/NNP)
#   in/IN
#   1996/CD
#   ,/,
#   succeeding/VBG
#   (ORGANIZATION Democratic/JJ)
#   State/NNP
#   Senator/NNP
#   Alice/NNP
#   Palmer/NNP
#   from/IN
#   (GPE Illinois/NNP)
#   's/POS
#   13th/JJ
#   (GPE District/NNP)
#   ,/,
#   which/WDT
#   ,/,
#   at/IN
#   that/DT
#   time/NN
#   ,/,
#   spanned/VBD
#   (PERSON Chicago/NNP South/NNP Side/NNP)
#   neighborhoods/NNS
#   from/IN
#   (PERSON Hyde/NNP)
#   Park–Kenwood/NNP
#   south/NN
#   to/TO
#   (GPE South/NNP Shore/NNP)
#   and/CC
#   west/JJS
#   to/TO
#   (GPE Chicago/NNP Lawn/NNP)
#   ./.
#   Once/RB
#   elected/VBN
#   ,/,
#   (PERSON Obama/NNP)
#   gained/VBD
#   bipartisan/JJ
#   support/NN
#   for/IN
#   legislation/NN
#   that/WDT
#   reformed/VBD
#   ethics/NNS
#   and/CC
#   health/NN
#   care/NN
#   laws/NNS
#   ./.
#   He/PRP
#   sponsored/VBD
#   a/DT
#   law/NN
#   that/WDT
#   increased/VBD
#   tax/NN
#   credits/NNS
#   for/IN
#   low-income/JJ
#   workers/NNS
#   ,/,
#   negotiated/VBN
#   welfare/NN
#   reform/NN
#   ,/,
#   and/CC
#   promoted/VBD
#   increased/VBN
#   subsidies/NNS
#   for/IN
#   childcare/NN
#   ./.
#   In/IN
#   2001/CD
#   ,/,
#   as/IN
#   co-chairman/NN
#   of/IN
#   the/DT
#   bipartisan/JJ
#   (ORGANIZATION Joint/NNP Committee/NNP)
#   on/IN
#   (ORGANIZATION Administrative/NNP Rules/NNP)
#   ,/,
#   (PERSON Obama/NNP)
#   supported/VBD
#   (ORGANIZATION Republican/NNP)
#   Governor/NNP
#   (PERSON Ryan/NNP)
#   's/POS
#   payday/NN
#   loan/NN
#   regulations/NNS
#   and/CC
#   predatory/JJ
#   mortgage/NN
#   lending/JJ
#   regulations/NNS
#   aimed/VBN
#   at/IN
#   averting/VBG
#   home/NN
#   foreclosures.He/NN
#   was/VBD
#   reelected/VBN
#   to/TO
#   the/DT
#   (ORGANIZATION Illinois/NNP Senate/NNP)
#   in/IN
#   1998/CD
#   ,/,
#   defeating/VBG
#   (ORGANIZATION Republican/NNP Yesse/NNP Yehudah/NNP)
#   in/IN
#   the/DT
#   general/JJ
#   election/NN
#   ,/,
#   and/CC
#   was/VBD
#   re-elected/VBN
#   again/RB
#   in/IN
#   2002/CD
#   ./.
#   In/IN
#   2000/CD
#   ,/,
#   he/PRP
#   lost/VBD
#   a/DT
#   (ORGANIZATION Democratic/JJ)
#   primary/JJ
#   race/NN
#   for/IN
#   (PERSON Illinois/NNP)
#   's/POS
#   1st/JJ
#   congressional/JJ
#   district/NN
#   in/IN
#   the/DT
#   (GPE United/NNP States/NNPS)
#   (ORGANIZATION House/NNP)
#   of/IN
#   (ORGANIZATION Representatives/NNPS)
#   to/TO
#   four-term/JJ
#   incumbent/JJ
#   (PERSON Bobby/NNP Rush/NNP)
#   by/IN
#   a/DT
#   margin/NN
#   of/IN
#   two/CD
#   to/TO
#   one.In/VB
#   January/NNP
#   2003/CD
#   ,/,
#   (PERSON Obama/NNP)
#   became/VBD
#   chairman/NN
#   of/IN
#   the/DT
#   (ORGANIZATION Illinois/NNP Senate/NNP)
#   's/POS
#   (ORGANIZATION Health/NNP)
#   and/CC
#   (PERSON Human/NNP Services/NNP Committee/NNP)
#   when/WRB
#   (ORGANIZATION Democrats/NNPS)
#   ,/,
#   after/IN
#   a/DT
#   decade/NN
#   in/IN
#   the/DT
#   minority/NN
#   ,/,
#   regained/VBD
#   a/DT
#   majority/NN
#   ./.
#   He/PRP
#   sponsored/VBD
#   and/CC
#   led/VBD
#   unanimous/JJ
#   ,/,
#   bipartisan/JJ
#   passage/NN
#   of/IN
#   legislation/NN
#   to/TO
#   monitor/VB
#   racial/JJ
#   profiling/NN
#   by/IN
#   requiring/VBG
#   police/NNS
#   to/TO
#   record/VB
#   the/DT
#   race/NN
#   of/IN
#   drivers/NNS
#   they/PRP
#   detained/VBD
#   ,/,
#   and/CC
#   legislation/NN
#   making/NN
#   Illinois/NNP
#   the/DT
#   first/JJ
#   state/NN
#   to/TO
#   mandate/VB
#   videotaping/NN
#   of/IN
#   homicide/JJ
#   interrogations/NNS
#   ./.
#   During/IN
#   his/PRP$
#   2004/CD
#   general/JJ
#   election/NN
#   campaign/NN
#   for/IN
#   the/DT
#   (GPE U.S./NNP)
#   (ORGANIZATION Senate/NNP)
#   ,/,
#   police/NN
#   representatives/NNS
#   credited/VBD
#   (PERSON Obama/NNP)
#   for/IN
#   his/PRP$
#   active/JJ
#   engagement/NN
#   with/IN
#   police/NN
#   organizations/NNS
#   in/IN
#   enacting/VBG
#   death/NN
#   penalty/NN
#   reforms/NNS
#   ./.
#   (PERSON Obama/NNP)
#   resigned/VBD
#   from/IN
#   the/DT
#   (ORGANIZATION Illinois/NNP Senate/NNP)
#   in/IN
#   November/NNP
#   2004/CD
#   following/VBG
#   his/PRP$
#   election/NN
#   to/TO
#   the/DT
#   (GPE U.S./NNP)
#   (ORGANIZATION Senate/NNP)
#   ./.
#   2004/CD
#   (GPE U.S./NNP)
#   (ORGANIZATION Senate/NNP)
#   campaign/NN
#   In/IN
#   May/NNP
#   2002/CD
#   ,/,
#   (PERSON Obama/NNP)
#   commissioned/VBD
#   a/DT
#   poll/NN
#   to/TO
#   assess/VB
#   his/PRP$
#   prospects/NNS
#   in/IN
#   a/DT
#   2004/CD
#   (GPE U.S./NNP)
#   (ORGANIZATION Senate/NNP)
#   race/NN
#   ./.
#   He/PRP
#   created/VBD
#   a/DT
#   campaign/NN
#   committee/NN
#   ,/,
#   began/VBD
#   raising/VBG
#   funds/NNS
#   ,/,
#   and/CC
#   lined/VBD
#   up/RP
#   political/JJ
#   media/NNS
#   consultant/NN
#   (PERSON David/NNP Axelrod/NNP)
#   by/IN
# ...
#   narration/NN
#   by/IN
#   the/DT
#   author/NN
#   category/NN
#   for/IN
#   the/DT
#   narration/NN
#   of/IN
#   his/PRP$
#   memoir/NN
#   A/DT
#   Promised/JJ
#   (GPE Land/NNP)
#   ./.
#   On/IN
#   April/NNP
#   5/CD
#   ,/,
#   2022/CD
#   ,/,
#   (PERSON Obama/NNP)
#   visited/VBD
#   the/DT
#   (FACILITY White/NNP House/NNP)
#   for/IN
#   the/DT
#   first/JJ
#   time/NN
#   since/IN
#   leaving/VBG
#   office/NN
#   ,/,
#   in/IN
#   an/DT
#   event/NN
#   celebrating/VBG
#   the/DT
#   12th/CD
#   annual/JJ
#   anniversary/NN
#   of/IN
#   the/DT
#   signing/NN
#   of/IN
#   the/DT
#   (ORGANIZATION Affordable/NNP Care/NNP)
#   Act.In/NNP
#   2022/CD
#   ,/,
#   he/PRP
#   narrated/VBD
#   the/DT
#   (ORGANIZATION Netflix/NNP)
#   documentary/JJ
#   series/NN
#   Our/PRP$
#   (ORGANIZATION Great/NNP National/NNP Parks/NNP)
#   ,/,
#   which/WDT
#   later/RB
#   won/VBD
#   him/PRP
#   a/DT
#   Primetime/NNP
#   Emmy/NNP
#   Award/NNP
#   for/IN
#   Outstanding/VBG
#   Narrator.In/NNP
#   June/NNP
#   2022/CD
#   ,/,
#   it/PRP
#   was/VBD
#   announced/VBN
#   that/IN
#   the/DT
#   (ORGANIZATION Obamas/NNP)
#   and/CC
#   their/PRP$
#   podcast/NN
#   production/NN
#   company/NN
#   ,/,
#   Higher/JJR
#   Ground/NN
#   ,/,
#   signed/VBD
#   a/DT
#   multi-year/JJ
#   deal/NN
#   with/IN
#   Audible.In/NNP
#   September/NNP
#   2022/CD
#   ,/,
#   (PERSON Obama/NNP)
#   visited/VBD
#   the/DT
#   (FACILITY White/NNP House/NNP)
#   to/TO
#   unveil/VB
#   his/PRP$
#   and/CC
#   (PERSON Michelle/NNP)
#   's/POS
#   official/JJ
#   (FACILITY White/NNP House/NNP)
#   portraits/NNS
#   ./.
#   (PERSON Legacy/NNP Historian/JJ Julian/NNP Zelizer/NNP)
#   credits/NNS
#   (PERSON Obama/NNP)
#   with/IN
#   ``/``
#   a/DT
#   keen/JJ
#   sense/NN
#   of/IN
#   how/WRB
#   the/DT
#   institutions/NNS
#   of/IN
#   government/NN
#   work/NN
#   and/CC
#   the/DT
#   ways/NNS
#   that/IN
#   his/PRP$
#   team/NN
#   could/MD
#   design/VB
#   policy/NN
#   proposals/NNS
#   ./.
#   ''/''
#   (PERSON Zelizer/NNP)
#   notes/VBZ
#   (PERSON Obama/NNP)
#   's/POS
#   policy/NN
#   successes/NNS
#   included/VBD
#   the/DT
#   economic/JJ
#   stimulus/NN
#   package/NN
#   which/WDT
#   ended/VBD
#   the/DT
#   (ORGANIZATION Great/JJ Recession/NNP)
#   and/CC
#   the/DT
#   Dodd-Frank/NNP
#   financial/JJ
#   and/CC
#   consumer/NN
#   protection/NN
#   reforms/NNS
#   ,/,
#   as/RB
#   well/RB
#   as/IN
#   the/DT
#   (ORGANIZATION Affordable/NNP Care/NNP Act/NNP)
#   ./.
#   (PERSON Zelizer/NNP)
#   also/RB
#   notes/VBZ
#   the/DT
#   (ORGANIZATION Democratic/NNP Party/NNP)
#   lost/VBD
#   power/NN
#   and/CC
#   numbers/NNS
#   of/IN
#   elected/JJ
#   officials/NNS
#   during/IN
#   (PERSON Obama/NNP)
#   's/POS
#   term/NN
#   ,/,
#   saying/VBG
#   that/IN
#   the/DT
#   consensus/NN
#   among/IN
#   historians/NNS
#   is/VBZ
#   that/IN
#   (PERSON Obama/NNP)
#   ``/``
#   turned/VBD
#   out/RP
#   to/TO
#   be/VB
#   a/DT
#   very/RB
#   effective/JJ
#   policymaker/NN
#   but/CC
#   not/RB
#   a/DT
#   tremendously/RB
#   successful/JJ
#   party/NN
#   builder/NN
#   ./.
#   ''/''
#   (PERSON Zelizer/NNP)
#   calls/VBZ
#   this/DT
#   the/DT
#   ``/``
#   defining/JJ
#   paradox/NN
#   of/IN
#   (PERSON Obama/NNP)
#   ’/NNP
#   s/VBD
#   presidency/NN
#   ''/''
#   .The/JJ
#   (ORGANIZATION Brookings/NNP Institution/NNP)
#   noted/VBD
#   that/IN
#   (PERSON Obama/NNP)
#   passed/VBD
#   ``/``
#   only/RB
#   one/CD
#   major/JJ
#   legislative/JJ
#   achievement/NN
#   (/(
#   (ORGANIZATION Obamacare/NNP)
#   )/)
#   —and/VBP
#   a/DT
#   fragile/JJ
#   one/CD
#   at/IN
#   that—the/JJ
#   legacy/NN
#   of/IN
#   (PERSON Obama/NNP)
#   ’/NNP
#   s/JJ
#   presidency/NN
#   mainly/RB
#   rests/VBZ
#   on/IN
#   its/PRP$
#   tremendous/JJ
#   symbolic/JJ
#   importance/NN
#   and/CC
#   the/DT
#   fate/NN
#   of/IN
#   a/DT
#   patchwork/NN
#   of/IN
#   executive/JJ
#   actions/NNS
#   ./.
#   ''/''
#   (PERSON David/NNP W./NNP Wise/NNP)
#   noted/VBD
#   that/IN
#   (PERSON Obama/NNP)
#   fell/VBD
#   short/JJ
#   ``/``
#   in/IN
#   areas/NNS
#   many/JJ
#   Progressives/NNS
#   hold/VBP
#   dear/JJ
#   ''/''
#   ,/,
#   including/VBG
#   the/DT
#   continuation/NN
#   of/IN
#   drone/NN
#   strikes/NNS
#   ,/,
#   not/RB
#   going/VBG
#   after/IN
#   big/JJ
#   banks/NNS
#   during/IN
#   the/DT
#   (ORGANIZATION Great/NNP Recession/NNP)
#   ,/,
#   and/CC
#   failing/VBG
#   to/TO
#   strengthen/VB
#   his/PRP$
#   coalition/NN
#   before/IN
#   pushing/VBG
#   for/IN
#   (ORGANIZATION Obamacare/NNP)
#   ./.
#   (PERSON Wise/NNP)
#   called/VBD
#   (PERSON Obama/NNP)
#   's/POS
#   legacy/NN
#   that/IN
#   of/IN
#   ``/``
#   a/DT
#   disappointingly/RB
#   conventional/JJ
#   president/NN
#   ''/''
#   .Obama/NNP
#   's/POS
#   most/RBS
#   significant/JJ
#   accomplishment/NN
#   is/VBZ
#   generally/RB
#   considered/VBN
#   to/TO
#   be/VB
#   the/DT
#   (ORGANIZATION Affordable/NNP Care/NNP Act/NNP)
#   (/(
#   (ORGANIZATION ACA/NNP)
#   )/)
#   ,/,
#   provisions/NNS
#   of/IN
#   which/WDT
#   went/VBD
#   into/IN
#   effect/NN
#   from/IN
#   2010/CD
#   to/TO
#   2020/CD
#   ./.
#   Many/JJ
#   attempts/NNS
#   by/IN
#   (ORGANIZATION Senate/NNP)
#   Republicans/NNPS
#   to/TO
#   repeal/VB
#   the/DT
#   (ORGANIZATION ACA/NNP)
#   ,/,
#   including/VBG
#   a/DT
#   ``/``
#   skinny/JJ
#   repeal/NN
#   ''/''
#   ,/,
#   have/VBP
#   thus/RB
#   far/RB
#   failed/VBD
#   ./.
#   However/RB
#   ,/,
#   in/IN
#   2017/CD
#   ,/,
#   the/DT
#   penalty/NN
#   for/IN
#   violating/VBG
#   the/DT
#   individual/JJ
#   mandate/NN
#   was/VBD
#   repealed/VBN
#   effective/JJ
#   2019/CD
#   ./.
#   Together/RB
#   with/IN
#   the/DT
#   (ORGANIZATION Health/NNP Care/NNP)
#   and/CC
#   (PERSON Education/NNP Reconciliation/NNP Act/NNP)
#   amendment/NN
#   ,/,
#   it/PRP
#   represents/VBZ
#   the/DT
#   (GPE U.S./NNP)
#   healthcare/NN
#   system/NN
#   's/POS
#   most/RBS
#   significant/JJ
#   regulatory/JJ
#   overhaul/NN
#   and/CC
#   expansion/NN
#   of/IN
#   coverage/NN
#   since/IN
#   the/DT
#   passage/NN
#   of/IN
#   (ORGANIZATION Medicare/NNP)
#   and/CC
#   (ORGANIZATION Medicaid/NNP)
#   in/IN
#   1965.Many/CD
#   commentators/NNS
#   credit/NN
#   (PERSON Obama/NNP)
#   with/IN
#   averting/VBG
#   a/DT
#   threatened/VBN
#   depression/NN
#   and/CC
#   pulling/VBG
#   the/DT
#   economy/NN
#   back/RB
#   from/IN
#   the/DT
#   (ORGANIZATION Great/NNP Recession/NNP)
#   ./.
#   According/VBG
#   to/TO
#   the/DT
#   (GPE U.S./NNP)
#   Bureau/NNP
#   of/IN
#   (ORGANIZATION Labor/NNP Statistics/NNPS)
#   ,/,
#   the/DT
#   (ORGANIZATION Obama/NNP)
#   administration/NN
#   created/VBD
#   11.3/CD
#   million/CD
#   jobs/NNS
#   from/IN
#   the/DT
#   month/NN
#   after/IN
#   his/PRP$
#   first/JJ
#   inauguration/NN
#   to/TO
#   the/DT
#   end/NN
#   of/IN
#   his/PRP$
#   term/NN
#   ./.
#   In/IN
#   2010/CD
#   ,/,
#   (PERSON Obama/NNP)
#   signed/VBD
#   into/IN
#   effect/NN
#   the/DT
#   (ORGANIZATION Dodd–Frank/NNP Wall/NNP Street/NNP Reform/NNP)
#   and/CC
#   (ORGANIZATION Consumer/NNP Protection/NNP Act/NNP)
#   ./.
#   Passed/VBN
#   as/IN
#   a/DT
#   response/NN
#   to/TO
#   the/DT
#   financial/JJ
#   crisis/NN
#   of/IN
#   2007–08/CD
#   ,/,
#   it/PRP
#   brought/VBD
#   the/DT
#   most/RBS
#   significant/JJ
#   changes/NNS
#   to/TO
#   financial/JJ
#   regulation/NN
#   in/IN
#   the/DT
#   (GPE United/NNP States/NNPS)
#   since/IN
#   the/DT
#   regulatory/JJ
#   reform/NN
#   that/WDT
#   followed/VBD
#   the/DT
#   (ORGANIZATION Great/NNP Depression/NNP)
#   under/IN
#   (ORGANIZATION Democratic/NNP)
#   President/NNP
#   (PERSON Franklin/NNP D./NNP)
#   Roosevelt.In/NNP
#   2009/CD
#   ,/,
#   (PERSON Obama/NNP)
#   signed/VBD
#   into/IN
#   law/NN
#   the/DT
#   (ORGANIZATION National/NNP Defense/NNP)
#   Authorization/NNP
#   Act/NNP
#   for/IN
#   (PERSON Fiscal/NNP)
#   Year/NNP
#   2010/CD
#   ,/,
#   which/WDT
#   contained/VBD
#   in/IN
#   it/PRP
#   the/DT
#   (ORGANIZATION Matthew/NNP Shepard/NNP)
#   and/CC
#   (PERSON James/NNP Byrd/NNP Jr/NNP)
#   ./.
#   (PERSON Hate/NNP Crimes/NNP)
#   Prevention/NNP
#   Act/NNP
#   ,/,
#   the/DT
#   first/JJ
#   addition/NN
#   to/TO
#   existing/VBG
#   federal/JJ
#   hate/NN
#   crime/NN
#   law/NN
#   in/IN
#   the/DT
#   (GPE United/NNP States/NNPS)
#   since/IN
#   (ORGANIZATION Democratic/JJ)
#   President/NNP
#   (PERSON Bill/NNP Clinton/NNP)
#   signed/VBD
#   into/IN
#   law/NN
#   the/DT
#   (ORGANIZATION Church/NNP Arson/NNP)
#   Prevention/NNP
#   Act/NNP
#   of/IN
#   1996/CD
#   ./.
#   The/DT
#   act/NN
#   expanded/VBD
#   existing/VBG
#   federal/JJ
#   hate/NN
#   crime/NN
#   laws/NNS
#   in/IN
#   the/DT
#   (GPE United/NNP States/NNPS)
#   ,/,
#   and/CC
#   made/VBD
#   it/PRP
#   a/DT
#   federal/JJ
#   crime/NN
#   to/TO
#   assault/VB
#   people/NNS
#   based/VBN
#   on/IN
#   sexual/JJ
#   orientation/NN
#   ,/,
#   gender/NN
#   identity/NN
#   ,/,
#   or/CC
#   disability.As/NN
#   president/NN
#   ,/,
#   (PERSON Obama/NNP)
#   advanced/VBD
#   (ORGANIZATION LGBT/NNP)
#   rights/NNS
#   ./.
#   In/IN
#   2010/CD
#   ,/,
#   he/PRP
#   signed/VBD
#   the/DT
#   Do/NNP
#   n't/RB
#   (PERSON Ask/NNP)
#   ,/,
#   Do/VBP
#   n't/RB
#   (ORGANIZATION Tell/NNP)
#   Repeal/NNP
#   Act/NNP
#   ,/,
#   which/WDT
#   brought/VBD
#   an/DT
#   end/NN
#   to/TO
#   ``/``
#   do/VB
#   n't/RB
#   ask/VB
#   ,/,
#   do/VBP
#   n't/RB
#   tell/VB
#   ''/''
#   policy/NN
#   in/IN
#   the/DT
#   (GPE U.S./NNP)
#   armed/VBD
#   forces/NNS
#   that/WDT
#   banned/VBD
#   open/JJ
#   service/NN
#   from/IN
#   (ORGANIZATION LGB/NNP)
#   people/NNS
#   ;/:
#   the/DT
#   law/NN
#   went/VBD
#   into/IN
#   effect/NN
#   the/DT
#   following/JJ
#   year/NN
#   ./.
#   In/IN
#   2016/CD
#   ,/,
#   his/PRP$
#   administration/NN
#   brought/VBD
#   an/DT
#   end/NN
#   to/TO
#   the/DT
#   ban/NN
#   on/IN
#   transgender/NN
#   people/NNS
#   serving/VBG
#   openly/RB
#   in/IN
#   the/DT
#   (GPE U.S./NNP)
#   armed/VBD
#   forces/NNS
#   ./.
#   A/DT
#   (GPE Gallup/NNP)
#   poll/NN
#   ,/,
#   taken/VBN
#   in/IN
#   the/DT
#   final/JJ
#   days/NNS
#   of/IN
#   (GPE Obama/NNP)
#   's/POS
#   term/NN
#   ,/,
#   showed/VBD
#   that/IN
#   68/CD
#   percent/NN
#   of/IN
#   (GPE Americans/NNPS)
#   believed/VBD
#   the/DT
#   (GPE U.S./NNP)
#   had/VBD
#   made/VBN
#   progress/NN
#   on/IN
#   (ORGANIZATION LGBT/NNP)
#   rights/NNS
#   during/IN
#   (PERSON Obama/NNP)
#   's/POS
#   eight/CD
#   years/NNS
#   in/IN
#   office.Obama/NN
#   substantially/RB
#   escalated/VBD
#   the/DT
#   use/NN
#   of/IN
#   drone/NN
#   strikes/NNS
#   against/IN
#   suspected/VBN
#   militants/NNS
#   and/CC
#   terrorists/NNS
#   associated/VBN
#   with/IN
#   al-Qaeda/JJ
#   and/CC
#   the/DT
#   (ORGANIZATION Taliban/NNP)
#   ./.
#   In/IN
#   2016/CD
#   ,/,
#   the/DT
#   last/JJ
#   year/NN
#   of/IN
#   his/PRP$
#   presidency/NN
#   ,/,
#   the/DT
#   (GPE U.S./NNP)
#   dropped/VBD
#   26,171/CD
#   bombs/NNS
#   on/IN
#   seven/CD
#   different/JJ
#   countries/NNS
#   ./.
#   (PERSON Obama/NNP)
#   left/VBD
#   about/RP
#   8,400/CD
#   (GPE U.S./NNP)
#   troops/NNS
#   in/IN
#   (GPE Afghanistan/NNP)
#   ,/,
#   5,262/CD
#   in/IN
#   (GPE Iraq/NNP)
#   ,/,
#   503/CD
#   in/IN
#   (GSP Syria/NNP)
#   ,/,
#   133/CD
#   in/IN
#   (GPE Pakistan/NNP)
#   ,/,
#   106/CD
#   in/IN
#   (GPE Somalia/NNP)
#   ,/,
#   seven/CD
#   in/IN
#   (GPE Yemen/NNP)
#   ,/,
#   and/CC
#   two/CD
#   in/IN
#   (GPE Libya/NNP)
#   at/IN
#   the/DT
#   end/NN
#   of/IN
#   his/PRP$
#   presidency.According/NN
#   to/TO
#   (PERSON Pew/NNP Research/NNP Center/NNP)
#   and/CC
#   (GPE United/NNP States/NNPS)
#   Bureau/NNP
#   of/IN
#   (ORGANIZATION Justice/NNP Statistics/NNPS)
#   ,/,
#   from/IN
#   December/NNP
#   31/CD
#   ,/,
#   2009/CD
#   ,/,
#   to/TO
#   December/NNP
#   31/CD
#   ,/,
#   2015/CD
#   ,/,
#   inmates/VBZ
#   sentenced/VBN
#   in/IN
#   (GPE U.S./NNP)
#   federal/JJ
#   custody/NN
#   declined/VBN
#   by/IN
#   five/CD
#   percent/NN
#   ./.
#   This/DT
#   is/VBZ
#   the/DT
#   largest/JJS
#   decline/NN
#   in/IN
#   sentenced/JJ
#   inmates/NNS
#   in/IN
#   (GPE U.S./NNP)
#   federal/JJ
#   custody/NN
#   since/IN
#   (ORGANIZATION Democratic/JJ)
#   President/NNP
#   (PERSON Jimmy/NNP Carter/NNP)
#   ./.
#   By/IN
#   contrast/NN
#   ,/,
#   the/DT
#   federal/JJ
#   prison/NN
#   population/NN
#   increased/VBD
#   significantly/RB
#   under/IN
#   presidents/NNS
#   (PERSON Ronald/NNP Reagan/NNP)
#   ,/,
#   (PERSON George/NNP H./NNP)
#   W./NNP
#   Bush/NNP
#   ,/,
#   (PERSON Bill/NNP Clinton/NNP)
#   ,/,
#   and/CC
#   (PERSON George/NNP W./NNP)
#   Bush.Human/NNP
#   Rights/NNP
#   Watch/NNP
#   (/(
#   (ORGANIZATION HRW/NNP)
#   )/)
#   called/VBD
#   (PERSON Obama/NNP)
#   's/POS
#   human/JJ
#   rights/NNS
#   record/NN
#   ``/``
#   mixed/JJ
#   ''/''
#   ,/,
#   adding/VBG
#   that/IN
#   ``/``
#   he/PRP
#   has/VBZ
#   often/RB
#   treated/VBN
#   human/JJ
#   rights/NNS
#   as/IN
#   a/DT
#   secondary/JJ
#   interest/NN
#   —/NN
#   nice/RB
#   to/TO
#   support/VB
#   when/WRB
#   the/DT
#   cost/NN
#   was/VBD
#   not/RB
#   too/RB
#   high/JJ
#   ,/,
#   but/CC
#   nothing/NN
#   like/IN
#   a/DT
#   top/JJ
#   priority/NN
#   he/PRP
#   championed/VBD
#   ./.
#   ``/``
#   (PERSON Obama/NNP)
#   left/VBD
#   office/NN
#   in/IN
#   January/NNP
#   2017/CD
#   with/IN
#   a/DT
#   60/CD
#   percent/NN
#   approval/NN
#   rating/NN
#   ./.
#   (PERSON Obama/NNP)
#   gained/VBD
#   10/CD
#   spots/NNS
#   from/IN
#   the/DT
#   same/JJ
#   survey/NN
#   in/IN
#   2015/CD
#   from/IN
#   the/DT
#   (ORGANIZATION Brookings/NNP)
#   Institution/NNP
#   that/IN
#   ranked/VBD
#   him/PRP
#   the/DT
#   18th-greatest/JJ
#   (GPE American/JJ)
#   president/NN
#   ./.
#   Presidential/NNP
#   library/VBD
#   The/DT
#   (ORGANIZATION Barack/NNP Obama/NNP)
#   Presidential/NNP
#   Center/NNP
#   is/VBZ
#   (PERSON Obama/NNP)
#   's/POS
#   planned/VBN
#   presidential/JJ
#   library/NN
#   ./.
#   It/PRP
#   will/MD
#   be/VB
#   hosted/VBN
#   by/IN
#   the/DT
#   (ORGANIZATION University/NNP)
#   of/IN
#   (GPE Chicago/NNP)
#   and/CC
#   located/VBN
#   in/IN
#   (PERSON Jackson/NNP Park/NNP)
#   on/IN
#   the/DT
#   (LOCATION South/NNP Side/NNP)
#   of/IN
#   (GPE Chicago/NNP)
#   ./.
#   (PERSON Bibliography/NNP See/NNP)
#   also/RB
#   (PERSON Politics/NNP DREAM/NNP Act/NNP Fraud/NNP Enforcement/NNP)
#   and/CC
#   (PERSON Recovery/NNP Act/NNP)
#   of/IN
#   2009/CD
#   Immigration/NNP
#   Reform/NNP
#   and/CC
#   (ORGANIZATION Control/NNP Act/NNP)
#   of/IN
#   1986/CD
#   IRS/NNP
#   targeting/VBG
#   controversy/NN
#   (GPE Middle/NNP)
#   Class/NNP
#   Tax/NNP
#   Relief/NNP
#   and/CC
#   (PERSON Job/NNP Creation/NNP Act/NNP)
#   of/IN
#   2012/CD
#   (ORGANIZATION National/NNP Broadband/NNP Plan/NNP)
#   (/(
#   (GPE United/NNP States/NNPS)
#   )/)
#   Office/NNP
#   of/IN
#   (ORGANIZATION Energy/NNP Efficiency/NNP)
#   and/CC
#   (PERSON Renewable/NNP Energy/NNP Social/NNP)
#   policy/NN
#   of/IN
#   the/DT
#   (ORGANIZATION Barack/NNP Obama/NNP)
#   administration/NN
#   (ORGANIZATION SPEECH/NNP Act/NNP Stay/NNP)
#   with/IN
#   It/PRP
#   (FACILITY White/NNP House/NNP)
#   Office/NNP
#   of/IN
#   (GPE Energy/NNP)
#   and/CC
#   (PERSON Climate/NNP Change/NNP Policy/NNP)
#   Other/JJ
#   (PERSON Roberts/NNP Court/NNP Speeches/NNP)
#   of/IN
#   (PERSON Barack/NNP Obama/NNP Lists/NNP)
#   Assassination/NNP
#   threats/NNS
#   against/IN
#   (PERSON Barack/NNP Obama/NNP List/NNP)
#   of/IN
#   African-American/NNP
#   (GPE United/NNP States/NNPS)
#   senators/NNS
#   List/NNP
#   of/IN
#   (PERSON Barack/NNP Obama/NNP)
#   2008/CD
#   presidential/JJ
#   campaign/NN
#   endorsements/NNS
#   List/NN
#   of/IN
#   (PERSON Barack/NNP Obama/NNP)
#   2012/CD
#   presidential/JJ
#   campaign/NN
#   endorsements/NNS
#   List/NNP
#   of/IN
#   federal/JJ
#   political/JJ
#   scandals/NNS
#   ,/,
#   2009–17/CD
#   List/NN
#   of/IN
#   people/NNS
#   granted/VBN
#   executive/JJ
#   clemency/NN
#   by/IN
#   (PERSON Barack/NNP Obama/NNP List/NNP)
#   of/IN
#   things/NNS
#   named/VBN
#   after/IN
#   (PERSON
#     Barack/NNP
#     Obama/NNP
#     References/NNP
#     Bibliography/NNP
#     Further/NNP)
#   reading/VBG
#   (ORGANIZATION External/NNP)
#   links/NNS
#   Official/NNP
#   Official/NNP
#   website/NN
#   of/IN
#   The/DT
#   (ORGANIZATION Obama/NNP Foundation/NNP)
#   Official/NNP
#   website/NN
#   of/IN
#   the/DT
#   (ORGANIZATION Barack/NNP Obama/NNP)
#   Presidential/NNP
#   Library/NNP
#   Official/NNP
#   website/NN
#   of/IN
#   Organizing/VBG
#   for/IN
#   (PERSON Action/NNP)
#   (FACILITY White/NNP House/NNP)
#   biography/NN
#   Other/JJ
#   (GPE Column/NNP)
#   archive/NN
#   at/IN
#   (FACILITY The/DT Huffington/NNP Post/NNP Barack/NNP Obama/NNP)
#   at/IN
#   (ORGANIZATION Curlie/NNP United/NNP States/NNPS)
#   (ORGANIZATION Congress/NNP)
#   ./.
#   ``/``
#   (PERSON Barack/NNP Obama/NNP)
#   (/(
#   id/NN
#   :/:
#   O000167/NN
#   )/)
#   ''/''
#   ./.
#   (PERSON Biographical/NNP Directory/NNP)
#   of/IN
#   the/DT
#   (GPE United/NNP States/NNPS)
#   (ORGANIZATION Congress/NNP)
#   ./.
#   Appearances/NNS
#   on/IN
#   C-SPAN/NNP
#   (PERSON Barack/NNP Obama/NNP)
#   at/IN
#   (ORGANIZATION IMDb/NNP Barack/NNP Obama/NNP)
#   collected/VBD
#   news/NN
#   and/CC
#   commentary/NN
#   at/IN
#   (FACILITY The/DT New/NNP York/NNP Times/NNP Barack/NNP Obama/NNP)
#   articles/VBZ
#   in/IN
#   the/DT
#   archive/NN
#   of/IN
#   the/DT
#   (ORGANIZATION Chicago/NNP Tribune/NNP Works/NNP)
#   by/IN
#   (PERSON Barack/NNP Obama/NNP)
#   at/IN
#   (ORGANIZATION Project/NNP Gutenberg/NNP Works/NNP)
#   by/IN
#   or/CC
#   about/IN
#   (PERSON Barack/NNP Obama/NNP)
#   at/IN
#   (ORGANIZATION Internet/NNP Archive/NNP Works/NNP)
#   by/IN
#   (PERSON Barack/NNP Obama/NNP)
#   at/IN
#   (ORGANIZATION LibriVox/NNP)
#   (/(
#   public/JJ
#   domain/VBP
#   audiobooks/NNS
#   )/)
#   Barack/VBP
#   (PERSON Obama/NNP)
#   on/IN
#   Nobelprize.org/NNP
#   (PERSON Barack/NNP Obama/NNP)
#   at/IN
#   (ORGANIZATION Politifact/NNP))

# %%
# !pip install wikipedia-api
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wikipedia-api
#   Downloading Wikipedia_API-0.5.8-py3-none-any.whl (13 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from wikipedia-api) (2.25.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->wikipedia-api) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->wikipedia-api) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->wikipedia-api) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->wikipedia-api) (1.24.3)
# Installing collected packages: wikipedia-api
# Successfully installed wikipedia-api-0.5.8

# %%
# !python -m spacy download en_core_web_sm
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 2023-02-14 17:47:30.965624: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-02-14 17:47:30.965750: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-02-14 17:47:30.965774: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-02-14 17:47:32.682701: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en-core-web-sm==3.4.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.4.1/en_core_web_sm-3.4.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 67.1 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /usr/local/lib/python3.8/dist-packages (from en-core-web-sm==3.4.1) (3.4.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.11.3)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.10.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.12)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.64.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.3.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.25.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.8)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.21.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.10.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.1.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (23.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.10.4)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.4.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.7)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.9)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (6.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (57.4.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.0.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
